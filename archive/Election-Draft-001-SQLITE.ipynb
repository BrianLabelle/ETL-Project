# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
import sqlalchemy as db
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
# Dependencies
import pandas as pd
import numpy as np
import psycopg2

# %%
# Create engine using the `demographics.sqlite` database file
engine = create_engine("sqlite:///data/election/database.sqlite")

# %%
# Declare a Base using `automap_base()`
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['county_facts']

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# %%
# Collect the names of tables within the database
inspector.get_table_names()
# Out:
# ['county_facts', 'county_facts_dictionary', 'primary_results']

# %%
# Assign the demographics class to a variable called `Demographics`
county_facts = Base.classes.county_facts

# %%
# Using the inspector to print the column names within the 'Salaries' table and its types
columns = inspector.get_columns('primary_results')
for column in columns:
    print(column["name"], column["type"])
# Out:
# state TEXT
# state_abbreviation TEXT
# county TEXT
# fips INTEGER
# party TEXT
# candidate TEXT
# votes INTEGER
# fraction_votes NUMERIC

# %%
# Create a session
session = Session(engine)

# %%
engine.execute("SELECT * FROM primary_results").fetchall()
# Out:
# [('Alabama', 'AL', 'Autauga', 1001, 'Democrat', 'Bernie Sanders', 544, 0.182),
#  ('Alabama', 'AL', 'Autauga', 1001, 'Democrat', 'Hillary Clinton', 2387, 0.8),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Democrat', 'Bernie Sanders', 2694, 0.32899999999999996),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Democrat', 'Hillary Clinton', 5290, 0.647),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Democrat', 'Bernie Sanders', 222, 0.078),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Democrat', 'Hillary Clinton', 2567, 0.9059999999999999),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Democrat', 'Bernie Sanders', 246, 0.19699999999999998),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Democrat', 'Hillary Clinton', 942, 0.755),
#  ('Alabama', 'AL', 'Blount', 1009, 'Democrat', 'Bernie Sanders', 395, 0.386),
#  ('Alabama', 'AL', 'Blount', 1009, 'Democrat', 'Hillary Clinton', 564, 0.551),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Democrat', 'Bernie Sanders', 178, 0.066),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Democrat', 'Hillary Clinton', 2451, 0.9129999999999999),
#  ('Alabama', 'AL', 'Butler', 1013, 'Democrat', 'Bernie Sanders', 156, 0.065),
#  ('Alabama', 'AL', 'Butler', 1013, 'Democrat', 'Hillary Clinton', 2196, 0.9209999999999999),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Democrat', 'Bernie Sanders', 1425, 0.218),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Democrat', 'Hillary Clinton', 5011, 0.765),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Democrat', 'Bernie Sanders', 312, 0.095),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Democrat', 'Hillary Clinton', 2899, 0.8859999999999999),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Democrat', 'Bernie Sanders', 268, 0.249),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Democrat', 'Hillary Clinton', 712, 0.6609999999999999),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Democrat', 'Bernie Sanders', 289, 0.24600000000000002),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Democrat', 'Hillary Clinton', 860, 0.731),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Democrat', 'Bernie Sanders', 273, 0.124),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Democrat', 'Hillary Clinton', 1772, 0.802),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Democrat', 'Bernie Sanders', 213, 0.063),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Democrat', 'Hillary Clinton', 3148, 0.93),
#  ('Alabama', 'AL', 'Clay', 1027, 'Democrat', 'Bernie Sanders', 135, 0.13699999999999998),
#  ('Alabama', 'AL', 'Clay', 1027, 'Democrat', 'Hillary Clinton', 807, 0.818),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Democrat', 'Bernie Sanders', 72, 0.23800000000000002),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Democrat', 'Hillary Clinton', 221, 0.732),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Democrat', 'Bernie Sanders', 389, 0.201),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Democrat', 'Hillary Clinton', 1493, 0.772),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Democrat', 'Bernie Sanders', 1342, 0.225),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Democrat', 'Hillary Clinton', 3879, 0.65),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Democrat', 'Bernie Sanders', 544, 0.191),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Democrat', 'Hillary Clinton', 2031, 0.7140000000000001),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Democrat', 'Bernie Sanders', 125, 0.10800000000000001),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Democrat', 'Hillary Clinton', 1012, 0.877),
#  ('Alabama', 'AL', 'Covington', 1039, 'Democrat', 'Bernie Sanders', 188, 0.19699999999999998),
#  ('Alabama', 'AL', 'Covington', 1039, 'Democrat', 'Hillary Clinton', 737, 0.773),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Democrat', 'Bernie Sanders', 107, 0.10300000000000001),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Democrat', 'Hillary Clinton', 908, 0.878),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Democrat', 'Bernie Sanders', 723, 0.345),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Democrat', 'Hillary Clinton', 1275, 0.608),
#  ('Alabama', 'AL', 'Dale', 1045, 'Democrat', 'Bernie Sanders', 415, 0.207),
#  ('Alabama', 'AL', 'Dale', 1045, 'Democrat', 'Hillary Clinton', 1544, 0.77),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Democrat', 'Bernie Sanders', 1774, 0.154),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Democrat', 'Hillary Clinton', 8577, 0.7440000000000001),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Democrat', 'Bernie Sanders', 667, 0.32299999999999995),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Democrat', 'Hillary Clinton', 1297, 0.629),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Democrat', 'Bernie Sanders', 694, 0.184),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Democrat', 'Hillary Clinton', 3019, 0.8009999999999999),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Democrat', 'Bernie Sanders', 226, 0.099),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Democrat', 'Hillary Clinton', 2027, 0.885),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Democrat', 'Bernie Sanders', 1289, 0.226),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Democrat', 'Hillary Clinton', 4262, 0.746),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Democrat', 'Bernie Sanders', 148, 0.172),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Democrat', 'Hillary Clinton', 660, 0.767),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Democrat', 'Bernie Sanders', 767, 0.301),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Democrat', 'Hillary Clinton', 1233, 0.484),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Democrat', 'Bernie Sanders', 157, 0.21600000000000003),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Democrat', 'Hillary Clinton', 544, 0.7490000000000001),
#  ('Alabama', 'AL', 'Greene', 1063, 'Democrat', 'Bernie Sanders', 213, 0.071),
#  ('Alabama', 'AL', 'Greene', 1063, 'Democrat', 'Hillary Clinton', 2714, 0.9009999999999999),
#  ('Alabama', 'AL', 'Hale', 1065, 'Democrat', 'Bernie Sanders', 427, 0.14),
#  ('Alabama', 'AL', 'Hale', 1065, 'Democrat', 'Hillary Clinton', 2426, 0.7959999999999999),
#  ('Alabama', 'AL', 'Henry', 1067, 'Democrat', 'Bernie Sanders', 163, 0.11900000000000001),
#  ('Alabama', 'AL', 'Henry', 1067, 'Democrat', 'Hillary Clinton', 1170, 0.856),
#  ('Alabama', 'AL', 'Houston', 1069, 'Democrat', 'Bernie Sanders', 780, 0.201),
#  ('Alabama', 'AL', 'Houston', 1069, 'Democrat', 'Hillary Clinton', 3044, 0.7829999999999999),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Democrat', 'Bernie Sanders', 510, 0.26899999999999996),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Democrat', 'Hillary Clinton', 1327, 0.7),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Democrat', 'Bernie Sanders', 14319, 0.174),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Democrat', 'Hillary Clinton', 67357, 0.816),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Democrat', 'Bernie Sanders', 173, 0.24100000000000002),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Democrat', 'Hillary Clinton', 442, 0.616),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Democrat', 'Bernie Sanders', 1745, 0.309),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Democrat', 'Hillary Clinton', 3676, 0.652),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Democrat', 'Bernie Sanders', 428, 0.162),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Democrat', 'Hillary Clinton', 2047, 0.777),
#  ('Alabama', 'AL', 'Lee', 1081, 'Democrat', 'Bernie Sanders', 2464, 0.254),
#  ('Alabama', 'AL', 'Lee', 1081, 'Democrat', 'Hillary Clinton', 7137, 0.736),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Democrat', 'Bernie Sanders', 1120, 0.255),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Democrat', 'Hillary Clinton', 3199, 0.728),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Democrat', 'Bernie Sanders', 330, 0.077),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Democrat', 'Hillary Clinton', 3782, 0.887),
#  ('Alabama', 'AL', 'Macon', 1087, 'Democrat', 'Bernie Sanders', 483, 0.1),
#  ('Alabama', 'AL', 'Macon', 1087, 'Democrat', 'Hillary Clinton', 4293, 0.892),
#  ('Alabama', 'AL', 'Madison', 1089, 'Democrat', 'Bernie Sanders', 8786, 0.301),
#  ('Alabama', 'AL', 'Madison', 1089, 'Democrat', 'Hillary Clinton', 19995, 0.6859999999999999),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Democrat', 'Bernie Sanders', 1092, 0.2),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Democrat', 'Hillary Clinton', 3590, 0.6579999999999999),
#  ('Alabama', 'AL', 'Marion', 1093, 'Democrat', 'Bernie Sanders', 256, 0.29600000000000004),
#  ('Alabama', 'AL', 'Marion', 1093, 'Democrat', 'Hillary Clinton', 567, 0.655),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Democrat', 'Bernie Sanders', 821, 0.341),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Democrat', 'Hillary Clinton', 1494, 0.621),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Democrat', 'Bernie Sanders', 5672, 0.162),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Democrat', 'Hillary Clinton', 28927, 0.8270000000000001),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Democrat', 'Bernie Sanders', 205, 0.076),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Democrat', 'Hillary Clinton', 2438, 0.909),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Democrat', 'Bernie Sanders', 4266, 0.128),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Democrat', 'Hillary Clinton', 28650, 0.862),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Democrat', 'Bernie Sanders', 1345, 0.252),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Democrat', 'Hillary Clinton', 3897, 0.731),
#  ('Alabama', 'AL', 'Perry', 1105, 'Democrat', 'Bernie Sanders', 389, 0.124),
#  ('Alabama', 'AL', 'Perry', 1105, 'Democrat', 'Hillary Clinton', 2575, 0.82),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Democrat', 'Bernie Sanders', 453, 0.14800000000000002),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Democrat', 'Hillary Clinton', 2326, 0.762),
#  ('Alabama', 'AL', 'Pike', 1109, 'Democrat', 'Bernie Sanders', 379, 0.145),
#  ('Alabama', 'AL', 'Pike', 1109, 'Democrat', 'Hillary Clinton', 2183, 0.8370000000000001),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Democrat', 'Bernie Sanders', 328, 0.187),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Democrat', 'Hillary Clinton', 1236, 0.706),
#  ('Alabama', 'AL', 'Russell', 1113, 'Democrat', 'Bernie Sanders', 988, 0.16399999999999998),
#  ('Alabama', 'AL', 'Russell', 1113, 'Democrat', 'Hillary Clinton', 4381, 0.728),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Democrat', 'Bernie Sanders', 3755, 0.354),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Democrat', 'Hillary Clinton', 6657, 0.628),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Democrat', 'Bernie Sanders', 745, 0.28600000000000003),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Democrat', 'Hillary Clinton', 1808, 0.693),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Democrat', 'Bernie Sanders', 416, 0.113),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Democrat', 'Hillary Clinton', 2987, 0.809),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Democrat', 'Bernie Sanders', 782, 0.122),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Democrat', 'Hillary Clinton', 5561, 0.865),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Democrat', 'Bernie Sanders', 308, 0.102),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Democrat', 'Hillary Clinton', 2658, 0.88),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Democrat', 'Bernie Sanders', 3444, 0.218),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Democrat', 'Hillary Clinton', 12136, 0.767),
#  ('Alabama', 'AL', 'Walker', 1127, 'Democrat', 'Bernie Sanders', 727, 0.275),
#  ('Alabama', 'AL', 'Walker', 1127, 'Democrat', 'Hillary Clinton', 1772, 0.6709999999999999),
#  ('Alabama', 'AL', 'Washington', 1129, 'Democrat', 'Bernie Sanders', 562, 0.214),
#  ('Alabama', 'AL', 'Washington', 1129, 'Democrat', 'Hillary Clinton', 1511, 0.575),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Democrat', 'Bernie Sanders', 410, 0.10400000000000001),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Democrat', 'Hillary Clinton', 3337, 0.843),
#  ('Alabama', 'AL', 'Winston', 1133, 'Democrat', 'Bernie Sanders', 138, 0.304),
#  ('Alabama', 'AL', 'Winston', 1133, 'Democrat', 'Hillary Clinton', 303, 0.667),
#  ('Alabama', 'AL', 'Autauga', 1001, 'Republican', 'Ben Carson', 1764, 0.146),
#  ('Alabama', 'AL', 'Autauga', 1001, 'Republican', 'Donald Trump', 5387, 0.445),
#  ('Alabama', 'AL', 'Autauga', 1001, 'Republican', 'John Kasich', 421, 0.035),
#  ('Alabama', 'AL', 'Autauga', 1001, 'Republican', 'Marco Rubio', 1785, 0.14800000000000002),
#  ('Alabama', 'AL', 'Autauga', 1001, 'Republican', 'Ted Cruz', 2482, 0.205),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Republican', 'Ben Carson', 4221, 0.084),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Republican', 'Donald Trump', 23618, 0.469),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Republican', 'John Kasich', 2987, 0.059000000000000004),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Republican', 'Marco Rubio', 9703, 0.193),
#  ('Alabama', 'AL', 'Baldwin', 1003, 'Republican', 'Ted Cruz', 8571, 0.17),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Republican', 'Ben Carson', 417, 0.122),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Republican', 'Donald Trump', 1710, 0.501),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Republican', 'John Kasich', 123, 0.036000000000000004),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Republican', 'Marco Rubio', 498, 0.146),
#  ('Alabama', 'AL', 'Barbour', 1005, 'Republican', 'Ted Cruz', 609, 0.179),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Republican', 'Ben Carson', 393, 0.099),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Republican', 'Donald Trump', 1959, 0.494),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Republican', 'John Kasich', 84, 0.021),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Republican', 'Marco Rubio', 444, 0.11199999999999999),
#  ('Alabama', 'AL', 'Bibb', 1007, 'Republican', 'Ted Cruz', 1011, 0.255),
#  ('Alabama', 'AL', 'Blount', 1009, 'Republican', 'Ben Carson', 1523, 0.1),
#  ('Alabama', 'AL', 'Blount', 1009, 'Republican', 'Donald Trump', 7390, 0.48700000000000004),
#  ('Alabama', 'AL', 'Blount', 1009, 'Republican', 'John Kasich', 337, 0.022000000000000002),
#  ('Alabama', 'AL', 'Blount', 1009, 'Republican', 'Marco Rubio', 1843, 0.122),
#  ('Alabama', 'AL', 'Blount', 1009, 'Republican', 'Ted Cruz', 3698, 0.244),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Republican', 'Ben Carson', 47, 0.085),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Republican', 'Donald Trump', 313, 0.565),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Republican', 'John Kasich', 23, 0.042),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Republican', 'Marco Rubio', 64, 0.11599999999999999),
#  ('Alabama', 'AL', 'Bullock', 1011, 'Republican', 'Ted Cruz', 94, 0.17),
#  ('Alabama', 'AL', 'Butler', 1013, 'Republican', 'Ben Carson', 377, 0.11800000000000001),
#  ('Alabama', 'AL', 'Butler', 1013, 'Republican', 'Donald Trump', 1720, 0.5379999999999999),
#  ('Alabama', 'AL', 'Butler', 1013, 'Republican', 'John Kasich', 86, 0.027000000000000003),
#  ('Alabama', 'AL', 'Butler', 1013, 'Republican', 'Marco Rubio', 427, 0.133),
#  ('Alabama', 'AL', 'Butler', 1013, 'Republican', 'Ted Cruz', 534, 0.16699999999999998),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Republican', 'Ben Carson', 2350, 0.11800000000000001),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Republican', 'Donald Trump', 8960, 0.451),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Republican', 'John Kasich', 957, 0.048),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Republican', 'Marco Rubio', 3251, 0.163),
#  ('Alabama', 'AL', 'Calhoun', 1015, 'Republican', 'Ted Cruz', 3859, 0.19399999999999998),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Republican', 'Ben Carson', 595, 0.131),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Republican', 'Donald Trump', 2169, 0.47600000000000003),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Republican', 'John Kasich', 168, 0.037000000000000005),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Republican', 'Marco Rubio', 595, 0.131),
#  ('Alabama', 'AL', 'Chambers', 1017, 'Republican', 'Ted Cruz', 914, 0.2),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Republican', 'Ben Carson', 534, 0.1),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Republican', 'Donald Trump', 2777, 0.521),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Republican', 'John Kasich', 151, 0.027999999999999997),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Republican', 'Marco Rubio', 810, 0.152),
#  ('Alabama', 'AL', 'Cherokee', 1019, 'Republican', 'Ted Cruz', 921, 0.17300000000000001),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Republican', 'Ben Carson', 1149, 0.10800000000000001),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Republican', 'Donald Trump', 5273, 0.493),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Republican', 'John Kasich', 218, 0.02),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Republican', 'Marco Rubio', 1436, 0.134),
#  ('Alabama', 'AL', 'Chilton', 1021, 'Republican', 'Ted Cruz', 2328, 0.218),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Republican', 'Ben Carson', 169, 0.079),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Republican', 'Donald Trump', 1070, 0.499),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Republican', 'John Kasich', 68, 0.032),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Republican', 'Marco Rubio', 315, 0.147),
#  ('Alabama', 'AL', 'Choctaw', 1023, 'Republican', 'Ted Cruz', 451, 0.21),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Republican', 'Ben Carson', 410, 0.08900000000000001),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Republican', 'Donald Trump', 2308, 0.502),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Republican', 'John Kasich', 125, 0.027000000000000003),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Republican', 'Marco Rubio', 805, 0.175),
#  ('Alabama', 'AL', 'Clarke', 1025, 'Republican', 'Ted Cruz', 886, 0.193),
#  ('Alabama', 'AL', 'Clay', 1027, 'Republican', 'Ben Carson', 492, 0.122),
#  ('Alabama', 'AL', 'Clay', 1027, 'Republican', 'Donald Trump', 1920, 0.47600000000000003),
#  ('Alabama', 'AL', 'Clay', 1027, 'Republican', 'John Kasich', 125, 0.031),
#  ('Alabama', 'AL', 'Clay', 1027, 'Republican', 'Marco Rubio', 505, 0.125),
#  ('Alabama', 'AL', 'Clay', 1027, 'Republican', 'Ted Cruz', 836, 0.207),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Republican', 'Ben Carson', 437, 0.1),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Republican', 'Donald Trump', 2120, 0.483),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Republican', 'John Kasich', 106, 0.024),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Republican', 'Marco Rubio', 598, 0.136),
#  ('Alabama', 'AL', 'Cleburne', 1029, 'Republican', 'Ted Cruz', 928, 0.21100000000000002),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Republican', 'Ben Carson', 1368, 0.132),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Republican', 'Donald Trump', 4304, 0.414),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Republican', 'John Kasich', 377, 0.036000000000000004),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Republican', 'Marco Rubio', 1608, 0.155),
#  ('Alabama', 'AL', 'Coffee', 1031, 'Republican', 'Ted Cruz', 2421, 0.233),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Republican', 'Ben Carson', 884, 0.109),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Republican', 'Donald Trump', 3858, 0.474),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Republican', 'John Kasich', 250, 0.031),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Republican', 'Marco Rubio', 1443, 0.177),
#  ('Alabama', 'AL', 'Colbert', 1033, 'Republican', 'Ted Cruz', 1601, 0.19699999999999998),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Republican', 'Ben Carson', 137, 0.105),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Republican', 'Donald Trump', 768, 0.59),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Republican', 'John Kasich', 17, 0.013000000000000001),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Republican', 'Marco Rubio', 141, 0.10800000000000001),
#  ('Alabama', 'AL', 'Conecuh', 1035, 'Republican', 'Ted Cruz', 208, 0.16),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Republican', 'Ben Carson', 201, 0.09),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Republican', 'Donald Trump', 1233, 0.5529999999999999),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Republican', 'John Kasich', 66, 0.03),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Republican', 'Marco Rubio', 241, 0.10800000000000001),
#  ('Alabama', 'AL', 'Coosa', 1037, 'Republican', 'Ted Cruz', 435, 0.195),
#  ('Alabama', 'AL', 'Covington', 1039, 'Republican', 'Ben Carson', 1275, 0.133),
#  ('Alabama', 'AL', 'Covington', 1039, 'Republican', 'Donald Trump', 4608, 0.48100000000000004),
#  ('Alabama', 'AL', 'Covington', 1039, 'Republican', 'John Kasich', 324, 0.034),
#  ('Alabama', 'AL', 'Covington', 1039, 'Republican', 'Marco Rubio', 1277, 0.133),
#  ('Alabama', 'AL', 'Covington', 1039, 'Republican', 'Ted Cruz', 1773, 0.185),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Republican', 'Ben Carson', 286, 0.10400000000000001),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Republican', 'Donald Trump', 1496, 0.545),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Republican', 'John Kasich', 70, 0.026000000000000002),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Republican', 'Marco Rubio', 250, 0.091),
#  ('Alabama', 'AL', 'Crenshaw', 1041, 'Republican', 'Ted Cruz', 602, 0.21899999999999997),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Republican', 'Ben Carson', 2301, 0.11),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Republican', 'Donald Trump', 10618, 0.506),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Republican', 'John Kasich', 558, 0.027000000000000003),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Republican', 'Marco Rubio', 2832, 0.135),
#  ('Alabama', 'AL', 'Cullman', 1043, 'Republican', 'Ted Cruz', 4248, 0.203),
#  ('Alabama', 'AL', 'Dale', 1045, 'Republican', 'Ben Carson', 1150, 0.125),
#  ('Alabama', 'AL', 'Dale', 1045, 'Republican', 'Donald Trump', 4151, 0.45299999999999996),
#  ('Alabama', 'AL', 'Dale', 1045, 'Republican', 'John Kasich', 333, 0.036000000000000004),
#  ('Alabama', 'AL', 'Dale', 1045, 'Republican', 'Marco Rubio', 1194, 0.13),
#  ('Alabama', 'AL', 'Dale', 1045, 'Republican', 'Ted Cruz', 2008, 0.21899999999999997),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Republican', 'Ben Carson', 46, 0.053),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Republican', 'Donald Trump', 523, 0.597),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Republican', 'John Kasich', 23, 0.026000000000000002),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Republican', 'Marco Rubio', 76, 0.087),
#  ('Alabama', 'AL', 'Dallas', 1047, 'Republican', 'Ted Cruz', 181, 0.207),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Republican', 'Ben Carson', 1285, 0.098),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Republican', 'Donald Trump', 6247, 0.47600000000000003),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Republican', 'John Kasich', 325, 0.025),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Republican', 'Marco Rubio', 2837, 0.21600000000000003),
#  ('Alabama', 'AL', 'DeKalb', 1049, 'Republican', 'Ted Cruz', 2153, 0.16399999999999998),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Republican', 'Ben Carson', 2630, 0.14800000000000002),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Republican', 'Donald Trump', 8525, 0.478),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Republican', 'John Kasich', 634, 0.036000000000000004),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Republican', 'Marco Rubio', 2387, 0.134),
#  ('Alabama', 'AL', 'Elmore', 1051, 'Republican', 'Ted Cruz', 3236, 0.182),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Republican', 'Ben Carson', 585, 0.102),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Republican', 'Donald Trump', 2817, 0.493),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Republican', 'John Kasich', 194, 0.034),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Republican', 'Marco Rubio', 1028, 0.18),
#  ('Alabama', 'AL', 'Escambia', 1053, 'Republican', 'Ted Cruz', 978, 0.171),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Republican', 'Ben Carson', 2098, 0.11199999999999999),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Republican', 'Donald Trump', 8657, 0.461),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Republican', 'John Kasich', 616, 0.033),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Republican', 'Marco Rubio', 3155, 0.168),
#  ('Alabama', 'AL', 'Etowah', 1055, 'Republican', 'Ted Cruz', 3891, 0.207),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Republican', 'Ben Carson', 488, 0.098),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Republican', 'Donald Trump', 2479, 0.499),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Republican', 'John Kasich', 124, 0.025),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Republican', 'Marco Rubio', 663, 0.133),
#  ('Alabama', 'AL', 'Fayette', 1057, 'Republican', 'Ted Cruz', 1043, 0.21),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Republican', 'Ben Carson', 388, 0.09300000000000001),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Republican', 'Donald Trump', 2155, 0.515),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Republican', 'John Kasich', 107, 0.026000000000000002),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Republican', 'Marco Rubio', 562, 0.134),
#  ('Alabama', 'AL', 'Franklin', 1059, 'Republican', 'Ted Cruz', 892, 0.213),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Republican', 'Ben Carson', 592, 0.09300000000000001),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Republican', 'Donald Trump', 3106, 0.486),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Republican', 'John Kasich', 146, 0.023),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Republican', 'Marco Rubio', 829, 0.13),
#  ('Alabama', 'AL', 'Geneva', 1061, 'Republican', 'Ted Cruz', 1517, 0.237),
#  ('Alabama', 'AL', 'Greene', 1063, 'Republican', 'Ben Carson', 19, 0.07),
#  ('Alabama', 'AL', 'Greene', 1063, 'Republican', 'Donald Trump', 147, 0.5379999999999999),
#  ('Alabama', 'AL', 'Greene', 1063, 'Republican', 'John Kasich', 10, 0.037000000000000005),
#  ('Alabama', 'AL', 'Greene', 1063, 'Republican', 'Marco Rubio', 33, 0.121),
#  ('Alabama', 'AL', 'Greene', 1063, 'Republican', 'Ted Cruz', 59, 0.21600000000000003),
#  ('Alabama', 'AL', 'Hale', 1065, 'Republican', 'Ben Carson', 88, 0.078),
#  ('Alabama', 'AL', 'Hale', 1065, 'Republican', 'Donald Trump', 590, 0.521),
#  ('Alabama', 'AL', 'Hale', 1065, 'Republican', 'John Kasich', 24, 0.021),
#  ('Alabama', 'AL', 'Hale', 1065, 'Republican', 'Marco Rubio', 132, 0.11699999999999999),
#  ('Alabama', 'AL', 'Hale', 1065, 'Republican', 'Ted Cruz', 283, 0.25),
#  ('Alabama', 'AL', 'Henry', 1067, 'Republican', 'Ben Carson', 436, 0.115),
#  ('Alabama', 'AL', 'Henry', 1067, 'Republican', 'Donald Trump', 1778, 0.46799999999999997),
#  ('Alabama', 'AL', 'Henry', 1067, 'Republican', 'John Kasich', 107, 0.027999999999999997),
#  ('Alabama', 'AL', 'Henry', 1067, 'Republican', 'Marco Rubio', 545, 0.14300000000000002),
#  ('Alabama', 'AL', 'Henry', 1067, 'Republican', 'Ted Cruz', 847, 0.223),
#  ('Alabama', 'AL', 'Houston', 1069, 'Republican', 'Ben Carson', 2310, 0.114),
#  ('Alabama', 'AL', 'Houston', 1069, 'Republican', 'Donald Trump', 8171, 0.40399999999999997),
#  ('Alabama', 'AL', 'Houston', 1069, 'Republican', 'John Kasich', 836, 0.040999999999999995),
#  ('Alabama', 'AL', 'Houston', 1069, 'Republican', 'Marco Rubio', 3683, 0.182),
#  ('Alabama', 'AL', 'Houston', 1069, 'Republican', 'Ted Cruz', 4558, 0.225),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Republican', 'Ben Carson', 1185, 0.10800000000000001),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Republican', 'Donald Trump', 5463, 0.499),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Republican', 'John Kasich', 310, 0.027999999999999997),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Republican', 'Marco Rubio', 1847, 0.16899999999999998),
#  ('Alabama', 'AL', 'Jackson', 1071, 'Republican', 'Ted Cruz', 1791, 0.16399999999999998),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Republican', 'Ben Carson', 8368, 0.08900000000000001),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Republican', 'Donald Trump', 32853, 0.35),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Republican', 'John Kasich', 5711, 0.061),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Republican', 'Marco Rubio', 23132, 0.247),
#  ('Alabama', 'AL', 'Jefferson', 1073, 'Republican', 'Ted Cruz', 22355, 0.23800000000000002),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Republican', 'Ben Carson', 344, 0.096),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Republican', 'Donald Trump', 1810, 0.504),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Republican', 'John Kasich', 103, 0.028999999999999998),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Republican', 'Marco Rubio', 466, 0.13),
#  ('Alabama', 'AL', 'Lamar', 1075, 'Republican', 'Ted Cruz', 692, 0.193),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Republican', 'Ben Carson', 2151, 0.121),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Republican', 'Donald Trump', 7502, 0.42100000000000004),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Republican', 'John Kasich', 983, 0.055),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Republican', 'Marco Rubio', 3320, 0.187),
#  ('Alabama', 'AL', 'Lauderdale', 1077, 'Republican', 'Ted Cruz', 3265, 0.183),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Republican', 'Ben Carson', 733, 0.107),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Republican', 'Donald Trump', 3604, 0.528),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Republican', 'John Kasich', 196, 0.028999999999999998),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Republican', 'Marco Rubio', 925, 0.135),
#  ('Alabama', 'AL', 'Lawrence', 1079, 'Republican', 'Ted Cruz', 1204, 0.17600000000000002),
#  ('Alabama', 'AL', 'Lee', 1081, 'Republican', 'Ben Carson', 2460, 0.11699999999999999),
#  ('Alabama', 'AL', 'Lee', 1081, 'Republican', 'Donald Trump', 6934, 0.33),
#  ('Alabama', 'AL', 'Lee', 1081, 'Republican', 'John Kasich', 1501, 0.071),
#  ('Alabama', 'AL', 'Lee', 1081, 'Republican', 'Marco Rubio', 4734, 0.225),
#  ('Alabama', 'AL', 'Lee', 1081, 'Republican', 'Ted Cruz', 4880, 0.23199999999999998),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Republican', 'Ben Carson', 2061, 0.10800000000000001),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Republican', 'Donald Trump', 8198, 0.43),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Republican', 'John Kasich', 746, 0.039),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Republican', 'Marco Rubio', 3602, 0.18899999999999997),
#  ('Alabama', 'AL', 'Limestone', 1083, 'Republican', 'Ted Cruz', 4082, 0.214),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Republican', 'Ben Carson', 88, 0.105),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Republican', 'Donald Trump', 500, 0.595),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Republican', 'John Kasich', 26, 0.031),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Republican', 'Marco Rubio', 83, 0.099),
#  ('Alabama', 'AL', 'Lowndes', 1085, 'Republican', 'Ted Cruz', 137, 0.163),
#  ('Alabama', 'AL', 'Macon', 1087, 'Republican', 'Ben Carson', 94, 0.127),
#  ('Alabama', 'AL', 'Macon', 1087, 'Republican', 'Donald Trump', 356, 0.48),
#  ('Alabama', 'AL', 'Macon', 1087, 'Republican', 'John Kasich', 39, 0.053),
#  ('Alabama', 'AL', 'Macon', 1087, 'Republican', 'Marco Rubio', 92, 0.124),
#  ('Alabama', 'AL', 'Macon', 1087, 'Republican', 'Ted Cruz', 147, 0.198),
#  ('Alabama', 'AL', 'Madison', 1089, 'Republican', 'Ben Carson', 6293, 0.096),
#  ('Alabama', 'AL', 'Madison', 1089, 'Republican', 'Donald Trump', 23791, 0.36200000000000004),
#  ('Alabama', 'AL', 'Madison', 1089, 'Republican', 'John Kasich', 3919, 0.06),
#  ('Alabama', 'AL', 'Madison', 1089, 'Republican', 'Marco Rubio', 17116, 0.26),
#  ('Alabama', 'AL', 'Madison', 1089, 'Republican', 'Ted Cruz', 13622, 0.207),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Republican', 'Ben Carson', 85, 0.079),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Republican', 'Donald Trump', 580, 0.539),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Republican', 'John Kasich', 26, 0.024),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Republican', 'Marco Rubio', 127, 0.11800000000000001),
#  ('Alabama', 'AL', 'Marengo', 1091, 'Republican', 'Ted Cruz', 228, 0.212),
#  ('Alabama', 'AL', 'Marion', 1093, 'Republican', 'Ben Carson', 589, 0.08900000000000001),
#  ('Alabama', 'AL', 'Marion', 1093, 'Republican', 'Donald Trump', 3503, 0.529),
#  ('Alabama', 'AL', 'Marion', 1093, 'Republican', 'John Kasich', 167, 0.025),
#  ('Alabama', 'AL', 'Marion', 1093, 'Republican', 'Marco Rubio', 921, 0.139),
#  ('Alabama', 'AL', 'Marion', 1093, 'Republican', 'Ted Cruz', 1268, 0.192),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Republican', 'Ben Carson', 1813, 0.098),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Republican', 'Donald Trump', 9115, 0.495),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Republican', 'John Kasich', 595, 0.032),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Republican', 'Marco Rubio', 3785, 0.20600000000000002),
#  ('Alabama', 'AL', 'Marshall', 1095, 'Republican', 'Ted Cruz', 2784, 0.151),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Republican', 'Ben Carson', 4824, 0.077),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Republican', 'Donald Trump', 28326, 0.452),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Republican', 'John Kasich', 2893, 0.046),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Republican', 'Marco Rubio', 11850, 0.18899999999999997),
#  ('Alabama', 'AL', 'Mobile', 1097, 'Republican', 'Ted Cruz', 13458, 0.215),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Republican', 'Ben Carson', 373, 0.099),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Republican', 'Donald Trump', 1966, 0.521),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Republican', 'John Kasich', 108, 0.028999999999999998),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Republican', 'Marco Rubio', 596, 0.158),
#  ('Alabama', 'AL', 'Monroe', 1099, 'Republican', 'Ted Cruz', 658, 0.174),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Republican', 'Ben Carson', 3379, 0.127),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Republican', 'Donald Trump', 10517, 0.39399999999999996),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Republican', 'John Kasich', 1953, 0.073),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Republican', 'Marco Rubio', 5570, 0.209),
#  ('Alabama', 'AL', 'Montgomery', 1101, 'Republican', 'Ted Cruz', 4700, 0.17600000000000002),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Republican', 'Ben Carson', 2790, 0.114),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Republican', 'Donald Trump', 10909, 0.446),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Republican', 'John Kasich', 1109, 0.045),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Republican', 'Marco Rubio', 4488, 0.183),
#  ('Alabama', 'AL', 'Morgan', 1103, 'Republican', 'Ted Cruz', 4828, 0.19699999999999998),
#  ('Alabama', 'AL', 'Perry', 1105, 'Republican', 'Ben Carson', 15, 0.04),
#  ('Alabama', 'AL', 'Perry', 1105, 'Republican', 'Donald Trump', 192, 0.515),
#  ('Alabama', 'AL', 'Perry', 1105, 'Republican', 'John Kasich', 2, 0.005),
#  ('Alabama', 'AL', 'Perry', 1105, 'Republican', 'Marco Rubio', 33, 0.08800000000000001),
#  ('Alabama', 'AL', 'Perry', 1105, 'Republican', 'Ted Cruz', 123, 0.33),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Republican', 'Ben Carson', 287, 0.113),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Republican', 'Donald Trump', 1124, 0.441),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Republican', 'John Kasich', 65, 0.025),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Republican', 'Marco Rubio', 353, 0.138),
#  ('Alabama', 'AL', 'Pickens', 1107, 'Republican', 'Ted Cruz', 658, 0.258),
#  ('Alabama', 'AL', 'Pike', 1109, 'Republican', 'Ben Carson', 698, 0.129),
#  ('Alabama', 'AL', 'Pike', 1109, 'Republican', 'Donald Trump', 2493, 0.46),
#  ('Alabama', 'AL', 'Pike', 1109, 'Republican', 'John Kasich', 172, 0.032),
#  ('Alabama', 'AL', 'Pike', 1109, 'Republican', 'Marco Rubio', 798, 0.147),
#  ('Alabama', 'AL', 'Pike', 1109, 'Republican', 'Ted Cruz', 1092, 0.201),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Republican', 'Ben Carson', 426, 0.09300000000000001),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Republican', 'Donald Trump', 2352, 0.516),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Republican', 'John Kasich', 133, 0.028999999999999998),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Republican', 'Marco Rubio', 584, 0.128),
#  ('Alabama', 'AL', 'Randolph', 1111, 'Republican', 'Ted Cruz', 942, 0.207),
#  ('Alabama', 'AL', 'Russell', 1113, 'Republican', 'Ben Carson', 298, 0.079),
#  ('Alabama', 'AL', 'Russell', 1113, 'Republican', 'Donald Trump', 1784, 0.474),
#  ('Alabama', 'AL', 'Russell', 1113, 'Republican', 'John Kasich', 106, 0.027999999999999997),
#  ('Alabama', 'AL', 'Russell', 1113, 'Republican', 'Marco Rubio', 463, 0.12300000000000001),
#  ('Alabama', 'AL', 'Russell', 1113, 'Republican', 'Ted Cruz', 1016, 0.27),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Republican', 'Ben Carson', 5005, 0.094),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Republican', 'Donald Trump', 18260, 0.344),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Republican', 'John Kasich', 2679, 0.05),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Republican', 'Marco Rubio', 12213, 0.23),
#  ('Alabama', 'AL', 'Shelby', 1117, 'Republican', 'Ted Cruz', 14005, 0.263),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Republican', 'Ben Carson', 2093, 0.109),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Republican', 'Donald Trump', 8596, 0.446),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Republican', 'John Kasich', 518, 0.027000000000000003),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Republican', 'Marco Rubio', 2586, 0.134),
#  ('Alabama', 'AL', 'St. Clair', 1115, 'Republican', 'Ted Cruz', 5178, 0.26899999999999996),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Republican', 'Ben Carson', 21, 0.075),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Republican', 'Donald Trump', 166, 0.591),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Republican', 'John Kasich', 4, 0.013999999999999999),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Republican', 'Marco Rubio', 39, 0.139),
#  ('Alabama', 'AL', 'Sumter', 1119, 'Republican', 'Ted Cruz', 45, 0.16),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Republican', 'Ben Carson', 1179, 0.095),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Republican', 'Donald Trump', 6304, 0.51),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Republican', 'John Kasich', 470, 0.038),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Republican', 'Marco Rubio', 1676, 0.136),
#  ('Alabama', 'AL', 'Talladega', 1121, 'Republican', 'Ted Cruz', 2468, 0.2),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Republican', 'Ben Carson', 1006, 0.114),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Republican', 'Donald Trump', 4658, 0.528),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Republican', 'John Kasich', 371, 0.042),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Republican', 'Marco Rubio', 1289, 0.146),
#  ('Alabama', 'AL', 'Tallapoosa', 1123, 'Republican', 'Ted Cruz', 1325, 0.15),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Republican', 'Ben Carson', 3310, 0.106),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Republican', 'Donald Trump', 11652, 0.375),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Republican', 'John Kasich', 1381, 0.044000000000000004),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Republican', 'Marco Rubio', 6333, 0.204),
#  ('Alabama', 'AL', 'Tuscaloosa', 1125, 'Republican', 'Ted Cruz', 7789, 0.25),
#  ('Alabama', 'AL', 'Walker', 1127, 'Republican', 'Ben Carson', 1369, 0.09),
#  ('Alabama', 'AL', 'Walker', 1127, 'Republican', 'Donald Trump', 8394, 0.551),
#  ('Alabama', 'AL', 'Walker', 1127, 'Republican', 'John Kasich', 362, 0.024),
#  ('Alabama', 'AL', 'Walker', 1127, 'Republican', 'Marco Rubio', 1652, 0.10800000000000001),
#  ('Alabama', 'AL', 'Walker', 1127, 'Republican', 'Ted Cruz', 3106, 0.204),
#  ('Alabama', 'AL', 'Washington', 1129, 'Republican', 'Ben Carson', 152, 0.064),
#  ('Alabama', 'AL', 'Washington', 1129, 'Republican', 'Donald Trump', 1269, 0.537),
#  ('Alabama', 'AL', 'Washington', 1129, 'Republican', 'John Kasich', 27, 0.011000000000000001),
#  ('Alabama', 'AL', 'Washington', 1129, 'Republican', 'Marco Rubio', 362, 0.153),
#  ('Alabama', 'AL', 'Washington', 1129, 'Republican', 'Ted Cruz', 516, 0.218),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Republican', 'Ben Carson', 44, 0.083),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Republican', 'Donald Trump', 287, 0.544),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Republican', 'John Kasich', 12, 0.023),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Republican', 'Marco Rubio', 64, 0.121),
#  ('Alabama', 'AL', 'Wilcox', 1131, 'Republican', 'Ted Cruz', 114, 0.21600000000000003),
#  ('Alabama', 'AL', 'Winston', 1133, 'Republican', 'Ben Carson', 539, 0.09),
#  ('Alabama', 'AL', 'Winston', 1133, 'Republican', 'Donald Trump', 3352, 0.561),
#  ('Alabama', 'AL', 'Winston', 1133, 'Republican', 'John Kasich', 163, 0.027000000000000003),
#  ('Alabama', 'AL', 'Winston', 1133, 'Republican', 'Marco Rubio', 708, 0.11900000000000001),
#  ('Alabama', 'AL', 'Winston', 1133, 'Republican', 'Ted Cruz', 1076, 0.18),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Democrat', 'Bernie Sanders', 9, 0.75),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Democrat', 'Hillary Clinton', 3, 0.25),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Democrat', 'Bernie Sanders', 8, 0.8),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Democrat', 'Hillary Clinton', 2, 0.2),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Democrat', 'Bernie Sanders', 9, 0.818),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Democrat', 'Hillary Clinton', 2, 0.182),
#  ('Alaska', 'AK', 'State House District 12', 90200112, 'Democrat', 'Bernie Sanders', 10, 1),
#  ('Alaska', 'AK', 'State House District 12', 90200112, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 13', 90200113, 'Democrat', 'Bernie Sanders', 5, 0.7140000000000001),
#  ('Alaska', 'AK', 'State House District 13', 90200113, 'Democrat', 'Hillary Clinton', 2, 0.28600000000000003),
#  ('Alaska', 'AK', 'State House District 14', 90200114, 'Democrat', 'Bernie Sanders', 9, 0.6920000000000001),
#  ('Alaska', 'AK', 'State House District 14', 90200114, 'Democrat', 'Hillary Clinton', 4, 0.308),
#  ('Alaska', 'AK', 'State House District 15', 90200115, 'Democrat', 'Bernie Sanders', 8, 0.889),
#  ('Alaska', 'AK', 'State House District 15', 90200115, 'Democrat', 'Hillary Clinton', 1, 0.111),
#  ('Alaska', 'AK', 'State House District 16', 90200116, 'Democrat', 'Bernie Sanders', 12, 0.8),
#  ('Alaska', 'AK', 'State House District 16', 90200116, 'Democrat', 'Hillary Clinton', 3, 0.2),
#  ('Alaska', 'AK', 'State House District 17', 90200117, 'Democrat', 'Bernie Sanders', 10, 0.7140000000000001),
#  ('Alaska', 'AK', 'State House District 17', 90200117, 'Democrat', 'Hillary Clinton', 4, 0.28600000000000003),
#  ('Alaska', 'AK', 'State House District 18', 90200118, 'Democrat', 'Bernie Sanders', 14, 0.778),
#  ('Alaska', 'AK', 'State House District 18', 90200118, 'Democrat', 'Hillary Clinton', 4, 0.222),
#  ('Alaska', 'AK', 'State House District 19', 90200119, 'Democrat', 'Bernie Sanders', 8, 0.667),
#  ('Alaska', 'AK', 'State House District 19', 90200119, 'Democrat', 'Hillary Clinton', 4, 0.33299999999999996),
#  ('Alaska', 'AK', 'State House District 2', 90200102, 'Democrat', 'Bernie Sanders', 5, 0.833),
#  ('Alaska', 'AK', 'State House District 2', 90200102, 'Democrat', 'Hillary Clinton', 1, 0.16699999999999998),
#  ('Alaska', 'AK', 'State House District 20', 90200120, 'Democrat', 'Bernie Sanders', 12, 0.667),
#  ('Alaska', 'AK', 'State House District 20', 90200120, 'Democrat', 'Hillary Clinton', 6, 0.33299999999999996),
#  ('Alaska', 'AK', 'State House District 21', 90200121, 'Democrat', 'Bernie Sanders', 12, 0.667),
#  ('Alaska', 'AK', 'State House District 21', 90200121, 'Democrat', 'Hillary Clinton', 6, 0.33299999999999996),
#  ('Alaska', 'AK', 'State House District 22', 90200122, 'Democrat', 'Bernie Sanders', 11, 0.7859999999999999),
#  ('Alaska', 'AK', 'State House District 22', 90200122, 'Democrat', 'Hillary Clinton', 3, 0.214),
#  ('Alaska', 'AK', 'State House District 23', 90200123, 'Democrat', 'Bernie Sanders', 13, 1),
#  ('Alaska', 'AK', 'State House District 23', 90200123, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 24', 90200124, 'Democrat', 'Bernie Sanders', 10, 0.667),
#  ('Alaska', 'AK', 'State House District 24', 90200124, 'Democrat', 'Hillary Clinton', 5, 0.33299999999999996),
#  ('Alaska', 'AK', 'State House District 25', 90200125, 'Democrat', 'Bernie Sanders', 11, 0.733),
#  ('Alaska', 'AK', 'State House District 25', 90200125, 'Democrat', 'Hillary Clinton', 4, 0.267),
#  ('Alaska', 'AK', 'State House District 26', 90200126, 'Democrat', 'Bernie Sanders', 10, 0.7140000000000001),
#  ('Alaska', 'AK', 'State House District 26', 90200126, 'Democrat', 'Hillary Clinton', 4, 0.28600000000000003),
#  ('Alaska', 'AK', 'State House District 27', 90200127, 'Democrat', 'Bernie Sanders', 13, 0.765),
#  ('Alaska', 'AK', 'State House District 27', 90200127, 'Democrat', 'Hillary Clinton', 4, 0.235),
#  ('Alaska', 'AK', 'State House District 28', 90200128, 'Democrat', 'Bernie Sanders', 14, 0.737),
#  ('Alaska', 'AK', 'State House District 28', 90200128, 'Democrat', 'Hillary Clinton', 5, 0.263),
#  ('Alaska', 'AK', 'State House District 29', 90200129, 'Democrat', 'Bernie Sanders', 8, 0.8),
#  ('Alaska', 'AK', 'State House District 29', 90200129, 'Democrat', 'Hillary Clinton', 2, 0.2),
#  ('Alaska', 'AK', 'State House District 3', 90200103, 'Democrat', 'Bernie Sanders', 7, 1),
#  ('Alaska', 'AK', 'State House District 3', 90200103, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 30', 90200130, 'Democrat', 'Bernie Sanders', 7, 0.778),
#  ('Alaska', 'AK', 'State House District 30', 90200130, 'Democrat', 'Hillary Clinton', 2, 0.222),
#  ('Alaska', 'AK', 'State House District 31', 90200131, 'Democrat', 'Bernie Sanders', 16, 1),
#  ('Alaska', 'AK', 'State House District 31', 90200131, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 32', 90200132, 'Democrat', 'Bernie Sanders', 13, 1),
#  ('Alaska', 'AK', 'State House District 32', 90200132, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 33', 90200133, 'Democrat', 'Bernie Sanders', 21, 0.84),
#  ('Alaska', 'AK', 'State House District 33', 90200133, 'Democrat', 'Hillary Clinton', 4, 0.16),
#  ('Alaska', 'AK', 'State House District 34', 90200134, 'Democrat', 'Bernie Sanders', 14, 0.778),
#  ('Alaska', 'AK', 'State House District 34', 90200134, 'Democrat', 'Hillary Clinton', 4, 0.222),
#  ('Alaska', 'AK', 'State House District 35', 90200135, 'Democrat', 'Bernie Sanders', 14, 0.778),
#  ('Alaska', 'AK', 'State House District 35', 90200135, 'Democrat', 'Hillary Clinton', 4, 0.222),
#  ('Alaska', 'AK', 'State House District 36', 90200136, 'Democrat', 'Bernie Sanders', 10, 0.833),
#  ('Alaska', 'AK', 'State House District 36', 90200136, 'Democrat', 'Hillary Clinton', 2, 0.16699999999999998),
#  ('Alaska', 'AK', 'State House District 37', 90200137, 'Democrat', 'Bernie Sanders', 11, 0.7859999999999999),
#  ('Alaska', 'AK', 'State House District 37', 90200137, 'Democrat', 'Hillary Clinton', 3, 0.214),
#  ('Alaska', 'AK', 'State House District 38', 90200138, 'Democrat', 'Bernie Sanders', 17, 1),
#  ('Alaska', 'AK', 'State House District 38', 90200138, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 39', 90200139, 'Democrat', 'Bernie Sanders', 13, 0.765),
#  ('Alaska', 'AK', 'State House District 39', 90200139, 'Democrat', 'Hillary Clinton', 4, 0.235),
#  ('Alaska', 'AK', 'State House District 4', 90200104, 'Democrat', 'Bernie Sanders', 16, 0.8420000000000001),
#  ('Alaska', 'AK', 'State House District 4', 90200104, 'Democrat', 'Hillary Clinton', 3, 0.158),
#  ('Alaska', 'AK', 'State House District 40', 90200140, 'Democrat', 'Bernie Sanders', 12, 1),
#  ('Alaska', 'AK', 'State House District 40', 90200140, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 5', 90200105, 'Democrat', 'Bernie Sanders', 15, 1),
#  ('Alaska', 'AK', 'State House District 5', 90200105, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 6', 90200106, 'Democrat', 'Bernie Sanders', 12, 1),
#  ('Alaska', 'AK', 'State House District 6', 90200106, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 7', 90200107, 'Democrat', 'Bernie Sanders', 6, 0.75),
#  ('Alaska', 'AK', 'State House District 7', 90200107, 'Democrat', 'Hillary Clinton', 2, 0.25),
#  ('Alaska', 'AK', 'State House District 8', 90200108, 'Democrat', 'Bernie Sanders', 7, 1),
#  ('Alaska', 'AK', 'State House District 8', 90200108, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Alaska', 'AK', 'State House District 9', 90200109, 'Democrat', 'Bernie Sanders', 8, 0.8),
#  ('Alaska', 'AK', 'State House District 9', 90200109, 'Democrat', 'Hillary Clinton', 2, 0.2),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Republican', 'Ben Carson', 26, 0.068),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Republican', 'Donald Trump', 134, 0.348),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Republican', 'John Kasich', 12, 0.031),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Republican', 'Marco Rubio', 62, 0.161),
#  ('Alaska', 'AK', 'State House District 1', 90200101, 'Republican', 'Ted Cruz', 151, 0.392),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Republican', 'Ben Carson', 80, 0.09699999999999999),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Republican', 'Donald Trump', 358, 0.436),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Republican', 'John Kasich', 18, 0.022000000000000002),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Republican', 'Marco Rubio', 83, 0.10099999999999999),
#  ('Alaska', 'AK', 'State House District 10', 90200110, 'Republican', 'Ted Cruz', 283, 0.344),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Republican', 'Ben Carson', 131, 0.12300000000000001),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Republican', 'Donald Trump', 323, 0.304),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Republican', 'John Kasich', 37, 0.035),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Republican', 'Marco Rubio', 118, 0.111),
#  ('Alaska', 'AK', 'State House District 11', 90200111, 'Republican', 'Ted Cruz', 455, 0.428),
#  ('Alaska', 'AK', 'State House District 12', 90200112, 'Republican', 'Ben Carson', 144, 0.136),
#  ('Alaska', 'AK', 'State House District 12', 90200112, 'Republican', 'Donald Trump', 315, 0.299),
# ...
#  ('Arizona', 'AZ', 'Pima', 4019, 'Republican', 'John Kasich', 9854, 0.11699999999999999),
#  ('Arizona', 'AZ', 'Pima', 4019, 'Republican', 'Ted Cruz', 23137, 0.27399999999999997),
#  ('Arizona', 'AZ', 'Pinal', 4021, 'Republican', 'Donald Trump', 12182, 0.575),
#  ('Arizona', 'AZ', 'Pinal', 4021, 'Republican', 'John Kasich', 1567, 0.07400000000000001),
#  ('Arizona', 'AZ', 'Pinal', 4021, 'Republican', 'Ted Cruz', 4079, 0.192),
#  ('Arizona', 'AZ', 'Santa Cruz', 4023, 'Republican', 'Donald Trump', 762, 0.452),
#  ('Arizona', 'AZ', 'Santa Cruz', 4023, 'Republican', 'John Kasich', 180, 0.107),
#  ('Arizona', 'AZ', 'Santa Cruz', 4023, 'Republican', 'Ted Cruz', 451, 0.268),
#  ('Arizona', 'AZ', 'Yavapai', 4025, 'Republican', 'Donald Trump', 17005, 0.47600000000000003),
#  ('Arizona', 'AZ', 'Yavapai', 4025, 'Republican', 'John Kasich', 3259, 0.091),
#  ('Arizona', 'AZ', 'Yavapai', 4025, 'Republican', 'Ted Cruz', 10547, 0.295),
#  ('Arizona', 'AZ', 'Yuma', 4027, 'Republican', 'Donald Trump', 4390, 0.495),
#  ('Arizona', 'AZ', 'Yuma', 4027, 'Republican', 'John Kasich', 522, 0.059000000000000004),
#  ('Arizona', 'AZ', 'Yuma', 4027, 'Republican', 'Ted Cruz', 2556, 0.28800000000000003),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Democrat', 'Bernie Sanders', 132, 0.152),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Democrat', 'Hillary Clinton', 724, 0.833),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Democrat', 'Bernie Sanders', 980, 0.33799999999999997),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Democrat', 'Hillary Clinton', 1375, 0.474),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Democrat', 'Bernie Sanders', 807, 0.36200000000000004),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Democrat', 'Hillary Clinton', 1391, 0.624),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Democrat', 'Bernie Sanders', 4696, 0.449),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Democrat', 'Hillary Clinton', 5650, 0.541),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Democrat', 'Bernie Sanders', 469, 0.385),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Democrat', 'Hillary Clinton', 721, 0.5920000000000001),
#  ('Arkansas', 'AR', 'Bradley', 5011, 'Democrat', 'Bernie Sanders', 106, 0.149),
#  ('Arkansas', 'AR', 'Bradley', 5011, 'Democrat', 'Hillary Clinton', 593, 0.8320000000000001),
#  ('Arkansas', 'AR', 'Calhoun', 5013, 'Democrat', 'Bernie Sanders', 312, 0.34),
#  ('Arkansas', 'AR', 'Calhoun', 5013, 'Democrat', 'Hillary Clinton', 413, 0.45),
#  ('Arkansas', 'AR', 'Carroll', 5015, 'Democrat', 'Bernie Sanders', 0, 0),
#  ('Arkansas', 'AR', 'Carroll', 5015, 'Democrat', 'Hillary Clinton', 0, 0),
#  ('Arkansas', 'AR', 'Chicot', 5017, 'Democrat', 'Bernie Sanders', 247, 0.146),
#  ('Arkansas', 'AR', 'Chicot', 5017, 'Democrat', 'Hillary Clinton', 1370, 0.8109999999999999),
#  ('Arkansas', 'AR', 'Clark', 5019, 'Democrat', 'Bernie Sanders', 494, 0.225),
#  ('Arkansas', 'AR', 'Clark', 5019, 'Democrat', 'Hillary Clinton', 1650, 0.752),
#  ('Arkansas', 'AR', 'Clay', 5021, 'Democrat', 'Bernie Sanders', 656, 0.355),
#  ('Arkansas', 'AR', 'Clay', 5021, 'Democrat', 'Hillary Clinton', 960, 0.52),
#  ('Arkansas', 'AR', 'Cleburne', 5023, 'Democrat', 'Bernie Sanders', 316, 0.28600000000000003),
#  ('Arkansas', 'AR', 'Cleburne', 5023, 'Democrat', 'Hillary Clinton', 758, 0.687),
#  ('Arkansas', 'AR', 'Cleveland', 5025, 'Democrat', 'Bernie Sanders', 137, 0.247),
#  ('Arkansas', 'AR', 'Cleveland', 5025, 'Democrat', 'Hillary Clinton', 382, 0.688),
#  ('Arkansas', 'AR', 'Columbia', 5027, 'Democrat', 'Bernie Sanders', 306, 0.22399999999999998),
#  ('Arkansas', 'AR', 'Columbia', 5027, 'Democrat', 'Hillary Clinton', 1008, 0.738),
#  ('Arkansas', 'AR', 'Conway', 5029, 'Democrat', 'Bernie Sanders', 840, 0.297),
#  ('Arkansas', 'AR', 'Conway', 5029, 'Democrat', 'Hillary Clinton', 1755, 0.621),
#  ('Arkansas', 'AR', 'Craighead', 5031, 'Democrat', 'Bernie Sanders', 1862, 0.336),
#  ('Arkansas', 'AR', 'Craighead', 5031, 'Democrat', 'Hillary Clinton', 3543, 0.64),
#  ('Arkansas', 'AR', 'Crawford', 5033, 'Democrat', 'Bernie Sanders', 874, 0.345),
#  ('Arkansas', 'AR', 'Crawford', 5033, 'Democrat', 'Hillary Clinton', 1586, 0.625),
#  ('Arkansas', 'AR', 'Crittenden', 5035, 'Democrat', 'Bernie Sanders', 722, 0.163),
#  ('Arkansas', 'AR', 'Crittenden', 5035, 'Democrat', 'Hillary Clinton', 3379, 0.764),
#  ('Arkansas', 'AR', 'Cross', 5037, 'Democrat', 'Bernie Sanders', 228, 0.217),
#  ('Arkansas', 'AR', 'Cross', 5037, 'Democrat', 'Hillary Clinton', 780, 0.742),
#  ('Arkansas', 'AR', 'Dallas', 5039, 'Democrat', 'Bernie Sanders', 361, 0.29600000000000004),
#  ('Arkansas', 'AR', 'Dallas', 5039, 'Democrat', 'Hillary Clinton', 693, 0.568),
#  ('Arkansas', 'AR', 'Desha', 5041, 'Democrat', 'Bernie Sanders', 449, 0.23),
#  ('Arkansas', 'AR', 'Desha', 5041, 'Democrat', 'Hillary Clinton', 1342, 0.6859999999999999),
#  ('Arkansas', 'AR', 'Drew', 5043, 'Democrat', 'Bernie Sanders', 475, 0.257),
#  ('Arkansas', 'AR', 'Drew', 5043, 'Democrat', 'Hillary Clinton', 1250, 0.6779999999999999),
#  ('Arkansas', 'AR', 'Faulkner', 5045, 'Democrat', 'Bernie Sanders', 2774, 0.39799999999999996),
#  ('Arkansas', 'AR', 'Faulkner', 5045, 'Democrat', 'Hillary Clinton', 4077, 0.586),
#  ('Arkansas', 'AR', 'Franklin', 5047, 'Democrat', 'Bernie Sanders', 294, 0.29600000000000004),
#  ('Arkansas', 'AR', 'Franklin', 5047, 'Democrat', 'Hillary Clinton', 667, 0.672),
#  ('Arkansas', 'AR', 'Fulton', 5049, 'Democrat', 'Bernie Sanders', 473, 0.374),
#  ('Arkansas', 'AR', 'Fulton', 5049, 'Democrat', 'Hillary Clinton', 701, 0.5539999999999999),
#  ('Arkansas', 'AR', 'Garland', 5051, 'Democrat', 'Bernie Sanders', 1779, 0.301),
#  ('Arkansas', 'AR', 'Garland', 5051, 'Democrat', 'Hillary Clinton', 4057, 0.687),
#  ('Arkansas', 'AR', 'Grant', 5053, 'Democrat', 'Bernie Sanders', 300, 0.28800000000000003),
#  ('Arkansas', 'AR', 'Grant', 5053, 'Democrat', 'Hillary Clinton', 690, 0.6629999999999999),
#  ('Arkansas', 'AR', 'Greene', 5055, 'Democrat', 'Bernie Sanders', 585, 0.31),
#  ('Arkansas', 'AR', 'Greene', 5055, 'Democrat', 'Hillary Clinton', 1236, 0.655),
#  ('Arkansas', 'AR', 'Hempstead', 5057, 'Democrat', 'Bernie Sanders', 164, 0.166),
#  ('Arkansas', 'AR', 'Hempstead', 5057, 'Democrat', 'Hillary Clinton', 786, 0.795),
#  ('Arkansas', 'AR', 'Hot Spring', 5059, 'Democrat', 'Bernie Sanders', 730, 0.297),
#  ('Arkansas', 'AR', 'Hot Spring', 5059, 'Democrat', 'Hillary Clinton', 1562, 0.637),
#  ('Arkansas', 'AR', 'Howard', 5061, 'Democrat', 'Bernie Sanders', 129, 0.185),
#  ('Arkansas', 'AR', 'Howard', 5061, 'Democrat', 'Hillary Clinton', 535, 0.765),
#  ('Arkansas', 'AR', 'Independence', 5063, 'Democrat', 'Bernie Sanders', 521, 0.317),
#  ('Arkansas', 'AR', 'Independence', 5063, 'Democrat', 'Hillary Clinton', 1059, 0.645),
#  ('Arkansas', 'AR', 'Izard', 5065, 'Democrat', 'Bernie Sanders', 239, 0.301),
#  ('Arkansas', 'AR', 'Izard', 5065, 'Democrat', 'Hillary Clinton', 516, 0.649),
#  ('Arkansas', 'AR', 'Jackson', 5067, 'Democrat', 'Bernie Sanders', 225, 0.23399999999999999),
#  ('Arkansas', 'AR', 'Jackson', 5067, 'Democrat', 'Hillary Clinton', 702, 0.73),
#  ('Arkansas', 'AR', 'Jefferson', 5069, 'Democrat', 'Bernie Sanders', 2115, 0.168),
#  ('Arkansas', 'AR', 'Jefferson', 5069, 'Democrat', 'Hillary Clinton', 9936, 0.787),
#  ('Arkansas', 'AR', 'Johnson', 5071, 'Democrat', 'Bernie Sanders', 580, 0.342),
#  ('Arkansas', 'AR', 'Johnson', 5071, 'Democrat', 'Hillary Clinton', 1056, 0.623),
#  ('Arkansas', 'AR', 'Lafayette', 5073, 'Democrat', 'Bernie Sanders', 160, 0.248),
#  ('Arkansas', 'AR', 'Lafayette', 5073, 'Democrat', 'Hillary Clinton', 443, 0.687),
#  ('Arkansas', 'AR', 'Lawrence', 5075, 'Democrat', 'Bernie Sanders', 726, 0.386),
#  ('Arkansas', 'AR', 'Lawrence', 5075, 'Democrat', 'Hillary Clinton', 933, 0.495),
#  ('Arkansas', 'AR', 'Lee', 5077, 'Democrat', 'Bernie Sanders', 84, 0.079),
#  ('Arkansas', 'AR', 'Lee', 5077, 'Democrat', 'Hillary Clinton', 956, 0.8959999999999999),
#  ('Arkansas', 'AR', 'Lincoln', 5079, 'Democrat', 'Bernie Sanders', 152, 0.192),
#  ('Arkansas', 'AR', 'Lincoln', 5079, 'Democrat', 'Hillary Clinton', 599, 0.757),
#  ('Arkansas', 'AR', 'Little River', 5081, 'Democrat', 'Bernie Sanders', 441, 0.325),
#  ('Arkansas', 'AR', 'Little River', 5081, 'Democrat', 'Hillary Clinton', 721, 0.531),
#  ('Arkansas', 'AR', 'Logan', 5083, 'Democrat', 'Bernie Sanders', 361, 0.282),
#  ('Arkansas', 'AR', 'Logan', 5083, 'Democrat', 'Hillary Clinton', 881, 0.6890000000000001),
#  ('Arkansas', 'AR', 'Lonoke', 5085, 'Democrat', 'Bernie Sanders', 817, 0.321),
#  ('Arkansas', 'AR', 'Lonoke', 5085, 'Democrat', 'Hillary Clinton', 1664, 0.654),
#  ('Arkansas', 'AR', 'Madison', 5087, 'Democrat', 'Bernie Sanders', 1078, 0.414),
#  ('Arkansas', 'AR', 'Madison', 5087, 'Democrat', 'Hillary Clinton', 1085, 0.41700000000000004),
#  ('Arkansas', 'AR', 'Marion', 5089, 'Democrat', 'Bernie Sanders', 314, 0.415),
#  ('Arkansas', 'AR', 'Marion', 5089, 'Democrat', 'Hillary Clinton', 421, 0.556),
#  ('Arkansas', 'AR', 'Miller', 5091, 'Democrat', 'Bernie Sanders', 356, 0.20800000000000002),
#  ('Arkansas', 'AR', 'Miller', 5091, 'Democrat', 'Hillary Clinton', 1300, 0.7609999999999999),
#  ('Arkansas', 'AR', 'Mississippi', 5093, 'Democrat', 'Bernie Sanders', 342, 0.139),
#  ('Arkansas', 'AR', 'Mississippi', 5093, 'Democrat', 'Hillary Clinton', 2017, 0.8190000000000001),
#  ('Arkansas', 'AR', 'Monroe', 5095, 'Democrat', 'Bernie Sanders', 411, 0.29600000000000004),
#  ('Arkansas', 'AR', 'Monroe', 5095, 'Democrat', 'Hillary Clinton', 843, 0.607),
#  ('Arkansas', 'AR', 'Montgomery', 5097, 'Democrat', 'Bernie Sanders', 142, 0.29600000000000004),
#  ('Arkansas', 'AR', 'Montgomery', 5097, 'Democrat', 'Hillary Clinton', 316, 0.66),
#  ('Arkansas', 'AR', 'Nevada', 5099, 'Democrat', 'Bernie Sanders', 306, 0.28),
#  ('Arkansas', 'AR', 'Nevada', 5099, 'Democrat', 'Hillary Clinton', 647, 0.5920000000000001),
#  ('Arkansas', 'AR', 'Newton', 5101, 'Democrat', 'Bernie Sanders', 211, 0.516),
#  ('Arkansas', 'AR', 'Newton', 5101, 'Democrat', 'Hillary Clinton', 192, 0.469),
#  ('Arkansas', 'AR', 'Ouachita', 5103, 'Democrat', 'Bernie Sanders', 525, 0.188),
#  ('Arkansas', 'AR', 'Ouachita', 5103, 'Democrat', 'Hillary Clinton', 2095, 0.7509999999999999),
#  ('Arkansas', 'AR', 'Perry', 5105, 'Democrat', 'Bernie Sanders', 428, 0.349),
#  ('Arkansas', 'AR', 'Perry', 5105, 'Democrat', 'Hillary Clinton', 648, 0.529),
#  ('Arkansas', 'AR', 'Phillips', 5107, 'Democrat', 'Bernie Sanders', 656, 0.183),
#  ('Arkansas', 'AR', 'Phillips', 5107, 'Democrat', 'Hillary Clinton', 2696, 0.754),
#  ('Arkansas', 'AR', 'Pike', 5109, 'Democrat', 'Bernie Sanders', 171, 0.299),
#  ('Arkansas', 'AR', 'Pike', 5109, 'Democrat', 'Hillary Clinton', 367, 0.642),
#  ('Arkansas', 'AR', 'Poinsett', 5111, 'Democrat', 'Bernie Sanders', 228, 0.23),
#  ('Arkansas', 'AR', 'Poinsett', 5111, 'Democrat', 'Hillary Clinton', 717, 0.7240000000000001),
#  ('Arkansas', 'AR', 'Polk', 5113, 'Democrat', 'Bernie Sanders', 272, 0.424),
#  ('Arkansas', 'AR', 'Polk', 5113, 'Democrat', 'Hillary Clinton', 349, 0.544),
#  ('Arkansas', 'AR', 'Pope', 5115, 'Democrat', 'Bernie Sanders', 1169, 0.4),
#  ('Arkansas', 'AR', 'Pope', 5115, 'Democrat', 'Hillary Clinton', 1680, 0.5760000000000001),
#  ('Arkansas', 'AR', 'Prairie', 5117, 'Democrat', 'Bernie Sanders', 385, 0.35700000000000004),
#  ('Arkansas', 'AR', 'Prairie', 5117, 'Democrat', 'Hillary Clinton', 558, 0.517),
#  ('Arkansas', 'AR', 'Pulaski', 5119, 'Democrat', 'Bernie Sanders', 10461, 0.22899999999999998),
#  ('Arkansas', 'AR', 'Pulaski', 5119, 'Democrat', 'Hillary Clinton', 34862, 0.764),
#  ('Arkansas', 'AR', 'Randolph', 5121, 'Democrat', 'Bernie Sanders', 356, 0.33299999999999996),
#  ('Arkansas', 'AR', 'Randolph', 5121, 'Democrat', 'Hillary Clinton', 662, 0.619),
#  ('Arkansas', 'AR', 'Saint Francis', 5123, 'Democrat', 'Bernie Sanders', 354, 0.15),
#  ('Arkansas', 'AR', 'Saint Francis', 5123, 'Democrat', 'Hillary Clinton', 1912, 0.8079999999999999),
#  ('Arkansas', 'AR', 'Saline', 5125, 'Democrat', 'Bernie Sanders', 2008, 0.311),
#  ('Arkansas', 'AR', 'Saline', 5125, 'Democrat', 'Hillary Clinton', 4358, 0.674),
#  ('Arkansas', 'AR', 'Scott', 5127, 'Democrat', 'Bernie Sanders', 151, 0.314),
#  ('Arkansas', 'AR', 'Scott', 5127, 'Democrat', 'Hillary Clinton', 306, 0.636),
#  ('Arkansas', 'AR', 'Searcy', 5129, 'Democrat', 'Bernie Sanders', 164, 0.418),
#  ('Arkansas', 'AR', 'Searcy', 5129, 'Democrat', 'Hillary Clinton', 221, 0.564),
#  ('Arkansas', 'AR', 'Sebastian', 5131, 'Democrat', 'Bernie Sanders', 2226, 0.368),
#  ('Arkansas', 'AR', 'Sebastian', 5131, 'Democrat', 'Hillary Clinton', 3694, 0.611),
#  ('Arkansas', 'AR', 'Sevier', 5133, 'Democrat', 'Bernie Sanders', 167, 0.304),
#  ('Arkansas', 'AR', 'Sevier', 5133, 'Democrat', 'Hillary Clinton', 342, 0.623),
#  ('Arkansas', 'AR', 'Sharp', 5135, 'Democrat', 'Bernie Sanders', 294, 0.31),
#  ('Arkansas', 'AR', 'Sharp', 5135, 'Democrat', 'Hillary Clinton', 608, 0.642),
#  ('Arkansas', 'AR', 'Stone', 5137, 'Democrat', 'Bernie Sanders', 421, 0.419),
#  ('Arkansas', 'AR', 'Stone', 5137, 'Democrat', 'Hillary Clinton', 547, 0.544),
#  ('Arkansas', 'AR', 'Union', 5139, 'Democrat', 'Bernie Sanders', 1669, 0.33),
#  ('Arkansas', 'AR', 'Union', 5139, 'Democrat', 'Hillary Clinton', 2548, 0.503),
#  ('Arkansas', 'AR', 'Van Buren', 5141, 'Democrat', 'Bernie Sanders', 436, 0.344),
#  ('Arkansas', 'AR', 'Van Buren', 5141, 'Democrat', 'Hillary Clinton', 770, 0.607),
#  ('Arkansas', 'AR', 'Washington', 5143, 'Democrat', 'Bernie Sanders', 8507, 0.479),
#  ('Arkansas', 'AR', 'Washington', 5143, 'Democrat', 'Hillary Clinton', 9110, 0.513),
#  ('Arkansas', 'AR', 'White', 5145, 'Democrat', 'Bernie Sanders', 818, 0.27899999999999997),
#  ('Arkansas', 'AR', 'White', 5145, 'Democrat', 'Hillary Clinton', 2024, 0.69),
#  ('Arkansas', 'AR', 'Woodruff', 5147, 'Democrat', 'Bernie Sanders', 292, 0.22399999999999998),
#  ('Arkansas', 'AR', 'Woodruff', 5147, 'Democrat', 'Hillary Clinton', 862, 0.662),
#  ('Arkansas', 'AR', 'Yell', 5149, 'Democrat', 'Bernie Sanders', 432, 0.348),
#  ('Arkansas', 'AR', 'Yell', 5149, 'Democrat', 'Hillary Clinton', 723, 0.5820000000000001),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Republican', 'Ben Carson', 146, 0.052000000000000005),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Republican', 'Donald Trump', 1073, 0.385),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Republican', 'John Kasich', 83, 0.03),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Republican', 'Marco Rubio', 789, 0.28300000000000003),
#  ('Arkansas', 'AR', 'Arkansas', 5001, 'Republican', 'Ted Cruz', 593, 0.213),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Republican', 'Ben Carson', 104, 0.07200000000000001),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Republican', 'Donald Trump', 586, 0.40399999999999997),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Republican', 'John Kasich', 45, 0.031),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Republican', 'Marco Rubio', 281, 0.19399999999999998),
#  ('Arkansas', 'AR', 'Ashley', 5003, 'Republican', 'Ted Cruz', 403, 0.278),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Republican', 'Ben Carson', 452, 0.052000000000000005),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Republican', 'Donald Trump', 3798, 0.43799999999999994),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Republican', 'John Kasich', 376, 0.043),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Republican', 'Marco Rubio', 1374, 0.159),
#  ('Arkansas', 'AR', 'Baxter', 5005, 'Republican', 'Ted Cruz', 2480, 0.28600000000000003),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Republican', 'Ben Carson', 2525, 0.06),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Republican', 'Donald Trump', 11828, 0.27899999999999997),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Republican', 'John Kasich', 2272, 0.054000000000000006),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Republican', 'Marco Rubio', 12863, 0.303),
#  ('Arkansas', 'AR', 'Benton', 5007, 'Republican', 'Ted Cruz', 11909, 0.281),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Republican', 'Ben Carson', 478, 0.075),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Republican', 'Donald Trump', 2577, 0.40700000000000003),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Republican', 'John Kasich', 267, 0.042),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Republican', 'Marco Rubio', 1213, 0.192),
#  ('Arkansas', 'AR', 'Boone', 5009, 'Republican', 'Ted Cruz', 1589, 0.251),
#  ('Arkansas', 'AR', 'Bradley', 5011, 'Republican', 'Ben Carson', 94, 0.054000000000000006),
#  ...]

# %%
# returns a list of states with incorrect fips associated to record
engine.execute("SELECT distinct(state_abbreviation) FROM primary_results where fips > 99999").fetchall()
# Out:
# [('AK',),
#  ('CT',),
#  ('IL',),
#  ('KS',),
#  ('ME',),
#  ('MA',),
#  ('NH',),
#  ('ND',),
#  ('RI',),
#  ('WY',)]

# %%
# returns a list of states with blank fips associated to record
engine.execute("SELECT * FROM primary_results WHERE fips = ''").fetchall()
# Out:
# [('New Hampshire', 'NH', 'Belknap', '', 'Democrat', 'Bernie Sanders', 5990, 0.6318565400843882),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Democrat', 'Hillary Clinton', 3490, 0.3681434599156118),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Democrat', 'Bernie Sanders', 5655, 0.6364659538548115),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Democrat', 'Hillary Clinton', 3230, 0.3635340461451885),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Democrat', 'Bernie Sanders', 12471, 0.7070930430345297),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Democrat', 'Hillary Clinton', 5166, 0.2929069569654703),
#  ('New Hampshire', 'NH', 'Coos', '', 'Democrat', 'Bernie Sanders', 3637, 0.643716814159292),
#  ('New Hampshire', 'NH', 'Coos', '', 'Democrat', 'Hillary Clinton', 2013, 0.35628318584070795),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Democrat', 'Bernie Sanders', 14258, 0.6733094068757084),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Democrat', 'Hillary Clinton', 6918, 0.32669059312429166),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Democrat', 'Bernie Sanders', 38646, 0.5790096636452169),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Democrat', 'Hillary Clinton', 28099, 0.4209903363547831),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Democrat', 'Bernie Sanders', 18076, 0.5968631335644708),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Democrat', 'Hillary Clinton', 12209, 0.40313686643552915),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Democrat', 'Bernie Sanders', 31080, 0.5765271105010296),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Democrat', 'Hillary Clinton', 22829, 0.4234728894989705),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Democrat', 'Bernie Sanders', 15865, 0.6431930592718722),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Democrat', 'Hillary Clinton', 8801, 0.3568069407281278),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Democrat', 'Bernie Sanders', 5906, 0.702844222301559),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Democrat', 'Hillary Clinton', 2497, 0.29715577769844104),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Ben Carson', 390, 0.025511872833126184),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Carly Fiorina', 672, 0.04395891934323281),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Chris Christie', 1001, 0.06548047360502388),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Donald Trump', 5505, 0.3601098972983581),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Jeb Bush', 1738, 0.11369137175377772),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'John Kasich', 2460, 0.1609210440243344),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Marco Rubio', 1504, 0.098384248053902),
#  ('New Hampshire', 'NH', 'Belknap', '', 'Republican', 'Ted Cruz', 2017, 0.1319421730882449),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Ben Carson', 280, 0.02312520647505781),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Carly Fiorina', 442, 0.03650479022134126),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Chris Christie', 884, 0.07300958044268252),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Donald Trump', 4182, 0.34539147670961345),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Jeb Bush', 1241, 0.10249421869838124),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'John Kasich', 2281, 0.18838784274859596),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Marco Rubio', 1433, 0.11835150313842088),
#  ('New Hampshire', 'NH', 'Carroll', '', 'Republican', 'Ted Cruz', 1365, 0.11273538156590684),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Ben Carson', 518, 0.039331814730447986),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Carly Fiorina', 565, 0.04290053151100987),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Chris Christie', 763, 0.05793470007593014),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Donald Trump', 4543, 0.3449506454062263),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Jeb Bush', 1501, 0.11397114654517844),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'John Kasich', 2178, 0.165375854214123),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Marco Rubio', 1237, 0.09392558845861806),
#  ('New Hampshire', 'NH', 'Cheshire', '', 'Republican', 'Ted Cruz', 1865, 0.1416097190584662),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Ben Carson', 170, 0.02981932994211542),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Carly Fiorina', 275, 0.048237151376951413),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Chris Christie', 355, 0.06226977723206455),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Donald Trump', 2183, 0.38291527802139974),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Jeb Bush', 561, 0.09840378880898087),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'John Kasich', 942, 0.1652341694439572),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Marco Rubio', 615, 0.10787581126118224),
#  ('New Hampshire', 'NH', 'Coos', '', 'Republican', 'Ted Cruz', 600, 0.10524469391334854),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Ben Carson', 470, 0.029197987202584333),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Carly Fiorina', 684, 0.04249238988631422),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Chris Christie', 1067, 0.06628564328756911),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Donald Trump', 4898, 0.3042803006771448),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Jeb Bush', 1864, 0.11579797477790893),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'John Kasich', 3475, 0.21587873516804373),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Marco Rubio', 1923, 0.11946325402248867),
#  ('New Hampshire', 'NH', 'Grafton', '', 'Republican', 'Ted Cruz', 1716, 0.1066037149779462),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Ben Carson', 1725, 0.021054301790531058),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Carly Fiorina', 3612, 0.04408587714052068),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Chris Christie', 7144, 0.08719532289365442),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Donald Trump', 28981, 0.3537244754732641),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Jeb Bush', 9575, 0.11686663167787528),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'John Kasich', 12504, 0.1526162258485799),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Marco Rubio', 8803, 0.10744406878959124),
#  ('New Hampshire', 'NH', 'Hillsborough', '', 'Republican', 'Ted Cruz', 9587, 0.11701309638598333),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Ben Carson', 753, 0.02322138958275511),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Carly Fiorina', 1511, 0.04659697165941962),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Chris Christie', 2377, 0.07330311160452709),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Donald Trump', 10966, 0.33817497764208837),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Jeb Bush', 3816, 0.1176797113516514),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'John Kasich', 6172, 0.19033521448175902),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Marco Rubio', 3056, 0.09424245227742313),
#  ('New Hampshire', 'NH', 'Merrimack', '', 'Republican', 'Ted Cruz', 3776, 0.11644617140037623),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Ben Carson', 1447, 0.01983903917079123),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Carly Fiorina', 2825, 0.03873205643226346),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Chris Christie', 5768, 0.07908194743408695),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Donald Trump', 28716, 0.3937096398261513),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Jeb Bush', 7747, 0.10621495263035222),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'John Kasich', 10370, 0.14217749564692816),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Marco Rubio', 8074, 0.11069827385277706),
#  ('New Hampshire', 'NH', 'Rockingham', '', 'Republican', 'Ted Cruz', 7990, 0.10954659500664958),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Ben Carson', 527, 0.024641137139383738),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Carly Fiorina', 825, 0.038574835180249685),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Chris Christie', 1233, 0.057651844578482256),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Donald Trump', 7352, 0.3437602281759948),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Jeb Bush', 2443, 0.11422826950951513),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'John Kasich', 3193, 0.14929630149156028),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Marco Rubio', 2492, 0.11651938093234207),
#  ('New Hampshire', 'NH', 'Strafford', '', 'Republican', 'Ted Cruz', 3322, 0.15532800299247207),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Ben Carson', 229, 0.028324056895485467),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Carly Fiorina', 295, 0.036487322201607914),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Chris Christie', 477, 0.05899814471243043),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Donald Trump', 3080, 0.38095238095238093),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Jeb Bush', 824, 0.10191713048855906),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'John Kasich', 1334, 0.16499690785405072),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Marco Rubio', 895, 0.11069882498453927),
#  ('New Hampshire', 'NH', 'Sullivan', '', 'Republican', 'Ted Cruz', 951, 0.11762523191094619)]

# %%
# 3 types of dataframes need to be created. 1 for good values, 1 for errorneous values, 1 for blank values.

df_election_all = engine.execute("SELECT * FROM primary_results").fetchall()
df_election_blank = engine.execute("SELECT * FROM primary_results WHERE fips = ''").fetchall()
df_election_fips_error = engine.execute("SELECT distinct(state_abbreviation) FROM primary_results where fips > 99999").fetchall()

# %%
type(df_election_fips_error)
# Out:
# list

# %%
# We imported FIPS CSV spreadsheet into a PostGres Database & created table via sql.
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:password@localhost:5432/etlproject')
connection = engine.connect()

df_FIPS = pd.read_sql_query('''SELECT * FROM public."FIPS" where state = 'AR';''', engine)
df_FIPS
# Out:
#     zipcode           county state   fips classfips
# 0     72003  Arkansas County    AR  05001        H1
# 1     72134  Arkansas County    AR  05001        H1
# 2     72166  Arkansas County    AR  05001        H1
# 3     72140  Arkansas County    AR  05001        H1
# 4     72048  Arkansas County    AR  05001        H1
# 5     72026  Arkansas County    AR  05001        H1
# 6     72055  Arkansas County    AR  05001        H1
# 7     72073  Arkansas County    AR  05001        H1
# 8     72038  Arkansas County    AR  05001        H1
# 9     72042  Arkansas County    AR  05001        H1
# 10    72160  Arkansas County    AR  05001        H1
# 11    71640    Ashley County    AR  05003        H1
# 12    71658    Ashley County    AR  05003        H1
# 13    71661    Ashley County    AR  05003        H1
# 14    71635    Ashley County    AR  05003        H1
# 15    71676    Ashley County    AR  05003        H1
# 16    71642    Ashley County    AR  05003        H1
# 17    71663    Ashley County    AR  05003        H1
# 18    71638    Ashley County    AR  05003        H1
# 19    71646    Ashley County    AR  05003        H1
# 20    71653    Ashley County    AR  05003        H1
# 21    72626    Baxter County    AR  05005        H1
# 22    72617    Baxter County    AR  05005        H1
# 23    72635    Baxter County    AR  05005        H1
# 24    72658    Baxter County    AR  05005        H1
# 25    72538    Baxter County    AR  05005        H1
# 26    72654    Baxter County    AR  05005        H1
# 27    72537    Baxter County    AR  05005        H1
# 28    72651    Baxter County    AR  05005        H1
# 29    72653    Baxter County    AR  05005        H1
# ..      ...              ...   ...    ...       ...
# 948   72082     White County    AR  05145        H1
# 949   72085     White County    AR  05145        H1
# 950   72136     White County    AR  05145        H1
# 951   72137     White County    AR  05145        H1
# 952   72145     White County    AR  05145        H1
# 953   72173     White County    AR  05145        H1
# 954   72012     White County    AR  05145        H1
# 955   72052     White County    AR  05145        H1
# 956   72396  Woodruff County    AR  05147        H1
# 957   72074  Woodruff County    AR  05147        H1
# 958   72101  Woodruff County    AR  05147        H1
# 959   72006  Woodruff County    AR  05147        H1
# 960   72392  Woodruff County    AR  05147        H1
# 961   72036  Woodruff County    AR  05147        H1
# 962   72059  Woodruff County    AR  05147        H1
# 963   72123  Woodruff County    AR  05147        H1
# 964   72112  Woodruff County    AR  05147        H1
# 965   72827      Yell County    AR  05149        H1
# 966   72860      Yell County    AR  05149        H1
# 967   72838      Yell County    AR  05149        H1
# 968   72829      Yell County    AR  05149        H1
# 969   72853      Yell County    AR  05149        H1
# 970   72841      Yell County    AR  05149        H1
# 971   72943      Yell County    AR  05149        H1
# 972   72833      Yell County    AR  05149        H1
# 973   72842      Yell County    AR  05149        H1
# 974   72834      Yell County    AR  05149        H1
# 975   72828      Yell County    AR  05149        H1
# 976   72824      Yell County    AR  05149        H1
# 977   72857      Yell County    AR  05149        H1
#
# [978 rows x 5 columns]
