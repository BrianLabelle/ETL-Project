# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
primary_results = 'data\election\primary_results_clean.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
# https://stackoverflow.com/questions/23836277/add-leading-zeros-to-strings-in-pandas-dataframe
df_election = pd.read_csv(primary_results, encoding="ISO-8859-1",converters={'fips': '{:0>5}'.format})

# %%
# Preview of the DataFrame
df_election.head()
# Out:
#      state state_abbreviation   county   fips       party        candidate  \
# 0  Alabama                 AL  Autauga  01001    Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  01001    Democrat  Hillary Clinton
# 2  Alabama                 AL  Autauga  01001  Republican       Ben Carson
# 3  Alabama                 AL  Autauga  01001  Republican     Donald Trump
# 4  Alabama                 AL  Autauga  01001  Republican      John Kasich
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   1764           0.146
# 3   5387           0.445
# 4    421           0.035

# %%
import pandas as pd
import sqlalchemy
import psycopg2
import matplotlib as plt
# %matplotlib inline

from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:password@localhost:5432/etlproject')
connection = engine.connect()

# %%
df_FIPS = pd.read_sql_query('''SELECT * FROM public."FIPS";''', engine)

# %%
df_FIPS.rename(columns={'ZIP':'zipcode','COUNTYNAME':'county','STATE':'state','STCOUNTYFP':'fips','CLASSFP':'classfp'},inplace=True)

# %%
df_FIPS
# Out:
#       zipcode                   county state   fips classfips
# 0       36003           Autauga County    AL  01001        H1
# 1       36006           Autauga County    AL  01001        H1
# 2       36067           Autauga County    AL  01001        H1
# 3       36066           Autauga County    AL  01001        H1
# 4       36703           Autauga County    AL  01001        H1
# 5       36701           Autauga County    AL  01001        H1
# 6       36091           Autauga County    AL  01001        H1
# 7       36051           Autauga County    AL  01001        H1
# 8       36068           Autauga County    AL  01001        H1
# 9       36008           Autauga County    AL  01001        H1
# 10      36022           Autauga County    AL  01001        H1
# 11      36749           Autauga County    AL  01001        H1
# 12      36758           Autauga County    AL  01001        H1
# 13      36550           Baldwin County    AL  01003        H1
# 14      36551           Baldwin County    AL  01003        H1
# 15      36527           Baldwin County    AL  01003        H1
# 16      36577           Baldwin County    AL  01003        H1
# 17      36559           Baldwin County    AL  01003        H1
# 18      36536           Baldwin County    AL  01003        H1
# 19      36576           Baldwin County    AL  01003        H1
# 20      36579           Baldwin County    AL  01003        H1
# 21      36502           Baldwin County    AL  01003        H1
# 22      36578           Baldwin County    AL  01003        H1
# 23      36533           Baldwin County    AL  01003        H1
# 24      36564           Baldwin County    AL  01003        H1
# 25      36561           Baldwin County    AL  01003        H1
# 26      36580           Baldwin County    AL  01003        H1
# 27      36535           Baldwin County    AL  01003        H1
# 28      36547           Baldwin County    AL  01003        H1
# 29      36549           Baldwin County    AL  01003        H1
# ...       ...                      ...   ...    ...       ...
# 52859   00924  Trujillo Alto Municipio    PR  72139        H1
# 52860   00976  Trujillo Alto Municipio    PR  72139        H1
# 52861   00957  Trujillo Alto Municipio    PR  72139        H1
# 52862   00778  Trujillo Alto Municipio    PR  72139        H1
# 52863   00961  Trujillo Alto Municipio    PR  72139        H1
# 52864   00962  Trujillo Alto Municipio    PR  72139        H1
# 52865   00917  Trujillo Alto Municipio    PR  72139        H1
# 52866   00641         Utuado Municipio    PR  72141        H1
# 52867   00612         Utuado Municipio    PR  72141        H1
# 52868   00611         Utuado Municipio    PR  72141        H1
# 52869   00687      Vega Alta Municipio    PR  72143        H1
# 52870   00646      Vega Alta Municipio    PR  72143        H1
# 52871   00692      Vega Alta Municipio    PR  72143        H1
# 52872   00692      Vega Baja Municipio    PR  72145        H1
# 52873   00674      Vega Baja Municipio    PR  72145        H1
# 52874   00687      Vega Baja Municipio    PR  72145        H1
# 52875   00693      Vega Baja Municipio    PR  72145        H1
# 52876   00694      Vega Baja Municipio    PR  72145        H1
# 52877   00765        Vieques Municipio    PR  72147        H1
# 52878   00766       Villalba Municipio    PR  72149        H1
# 52879   00720       Villalba Municipio    PR  72149        H1
# 52880   00767        Yabucoa Municipio    PR  72151        H1
# 52881   00653          Yauco Municipio    PR  72153        H1
# 52882   00606          Yauco Municipio    PR  72153        H1
# 52883   00698          Yauco Municipio    PR  72153        H1
# 52884   00850         St. Croix Island    VI  78010        H4
# 52885   00840         St. Croix Island    VI  78010        H4
# 52886   00820         St. Croix Island    VI  78010        H4
# 52887   00830          St. John Island    VI  78020        H4
# 52888   00802        St. Thomas Island    VI  78030        H4
#
# [52889 rows x 5 columns]

# %%
df_merge = pd.merge(df_election, df_FIPS, how="left", on=["fips", "fips"])

# %%
df_merge.rename(columns={"county_y":"county"})
# Out:
#         state_x state_abbreviation county_x   fips       party  \
# 0       Alabama                 AL  Autauga  01001    Democrat
# 1       Alabama                 AL  Autauga  01001    Democrat
# 2       Alabama                 AL  Autauga  01001    Democrat
# 3       Alabama                 AL  Autauga  01001    Democrat
# 4       Alabama                 AL  Autauga  01001    Democrat
# 5       Alabama                 AL  Autauga  01001    Democrat
# 6       Alabama                 AL  Autauga  01001    Democrat
# 7       Alabama                 AL  Autauga  01001    Democrat
# 8       Alabama                 AL  Autauga  01001    Democrat
# 9       Alabama                 AL  Autauga  01001    Democrat
# 10      Alabama                 AL  Autauga  01001    Democrat
# 11      Alabama                 AL  Autauga  01001    Democrat
# 12      Alabama                 AL  Autauga  01001    Democrat
# 13      Alabama                 AL  Autauga  01001    Democrat
# 14      Alabama                 AL  Autauga  01001    Democrat
# 15      Alabama                 AL  Autauga  01001    Democrat
# 16      Alabama                 AL  Autauga  01001    Democrat
# 17      Alabama                 AL  Autauga  01001    Democrat
# 18      Alabama                 AL  Autauga  01001    Democrat
# 19      Alabama                 AL  Autauga  01001    Democrat
# 20      Alabama                 AL  Autauga  01001    Democrat
# 21      Alabama                 AL  Autauga  01001    Democrat
# 22      Alabama                 AL  Autauga  01001    Democrat
# 23      Alabama                 AL  Autauga  01001    Democrat
# 24      Alabama                 AL  Autauga  01001    Democrat
# 25      Alabama                 AL  Autauga  01001    Democrat
# 26      Alabama                 AL  Autauga  01001  Republican
# 27      Alabama                 AL  Autauga  01001  Republican
# 28      Alabama                 AL  Autauga  01001  Republican
# 29      Alabama                 AL  Autauga  01001  Republican
# ...         ...                ...      ...    ...         ...
# 578073  Wyoming                 WY  Laramie  56001  Republican
# 578074  Wyoming                 WY  Laramie  56001  Republican
# 578075  Wyoming                 WY  Laramie  56001  Republican
# 578076  Wyoming                 WY  Laramie  56001  Republican
# 578077  Wyoming                 WY  Laramie  56001  Republican
# 578078  Wyoming                 WY  Laramie  56001  Republican
# 578079  Wyoming                 WY  Laramie  56001  Republican
# 578080  Wyoming                 WY  Laramie  56001  Republican
# 578081  Wyoming                 WY  Laramie  56001  Republican
# 578082  Wyoming                 WY  Laramie  56001  Republican
# 578083  Wyoming                 WY  Laramie  56001  Republican
# 578084  Wyoming                 WY  Laramie  56001  Republican
# 578085  Wyoming                 WY  Laramie  56001  Republican
# 578086  Wyoming                 WY  Laramie  56001  Republican
# 578087  Wyoming                 WY  Laramie  56001  Republican
# 578088  Wyoming                 WY  Laramie  56001  Republican
# 578089  Wyoming                 WY  Laramie  56001  Republican
# 578090  Wyoming                 WY  Laramie  56001  Republican
# 578091  Wyoming                 WY  Laramie  56001  Republican
# 578092  Wyoming                 WY  Laramie  56001  Republican
# 578093  Wyoming                 WY  Laramie  56001  Republican
# 578094  Wyoming                 WY  Laramie  56001  Republican
# 578095  Wyoming                 WY  Laramie  56001  Republican
# 578096  Wyoming                 WY  Laramie  56001  Republican
# 578097  Wyoming                 WY  Laramie  56001  Republican
# 578098  Wyoming                 WY  Laramie  56001  Republican
# 578099  Wyoming                 WY  Laramie  56001  Republican
# 578100  Wyoming                 WY  Laramie  56001  Republican
# 578101  Wyoming                 WY  Laramie  56001  Republican
# 578102  Wyoming                 WY  Laramie  56001  Republican
#
#               candidate  votes  fraction_votes zipcode          county  \
# 0        Bernie Sanders    544           0.182   36003  Autauga County
# 1        Bernie Sanders    544           0.182   36006  Autauga County
# 2        Bernie Sanders    544           0.182   36067  Autauga County
# 3        Bernie Sanders    544           0.182   36066  Autauga County
# 4        Bernie Sanders    544           0.182   36703  Autauga County
# 5        Bernie Sanders    544           0.182   36701  Autauga County
# 6        Bernie Sanders    544           0.182   36091  Autauga County
# 7        Bernie Sanders    544           0.182   36051  Autauga County
# 8        Bernie Sanders    544           0.182   36068  Autauga County
# 9        Bernie Sanders    544           0.182   36008  Autauga County
# 10       Bernie Sanders    544           0.182   36022  Autauga County
# 11       Bernie Sanders    544           0.182   36749  Autauga County
# 12       Bernie Sanders    544           0.182   36758  Autauga County
# 13      Hillary Clinton   2387           0.800   36003  Autauga County
# 14      Hillary Clinton   2387           0.800   36006  Autauga County
# 15      Hillary Clinton   2387           0.800   36067  Autauga County
# 16      Hillary Clinton   2387           0.800   36066  Autauga County
# 17      Hillary Clinton   2387           0.800   36703  Autauga County
# 18      Hillary Clinton   2387           0.800   36701  Autauga County
# 19      Hillary Clinton   2387           0.800   36091  Autauga County
# 20      Hillary Clinton   2387           0.800   36051  Autauga County
# 21      Hillary Clinton   2387           0.800   36068  Autauga County
# 22      Hillary Clinton   2387           0.800   36008  Autauga County
# 23      Hillary Clinton   2387           0.800   36022  Autauga County
# 24      Hillary Clinton   2387           0.800   36749  Autauga County
# 25      Hillary Clinton   2387           0.800   36758  Autauga County
# 26           Ben Carson   1764           0.146   36003  Autauga County
# 27           Ben Carson   1764           0.146   36006  Autauga County
# 28           Ben Carson   1764           0.146   36067  Autauga County
# 29           Ben Carson   1764           0.146   36066  Autauga County
# ...                 ...    ...             ...     ...             ...
# 578073      John Kasich      0           0.000   82052   Albany County
# 578074      John Kasich      0           0.000   82071   Albany County
# 578075      Marco Rubio     38           0.176   82329   Albany County
# 578076      Marco Rubio     38           0.176   82055   Albany County
# 578077      Marco Rubio     38           0.176   82070   Albany County
# 578078      Marco Rubio     38           0.176   82058   Albany County
# 578079      Marco Rubio     38           0.176   82051   Albany County
# 578080      Marco Rubio     38           0.176   82201   Albany County
# 578081      Marco Rubio     38           0.176   82059   Albany County
# 578082      Marco Rubio     38           0.176   82063   Albany County
# 578083      Marco Rubio     38           0.176   82073   Albany County
# 578084      Marco Rubio     38           0.176   82072   Albany County
# 578085      Marco Rubio     38           0.176   82083   Albany County
# 578086      Marco Rubio     38           0.176   82084   Albany County
# 578087      Marco Rubio     38           0.176   82052   Albany County
# 578088      Marco Rubio     38           0.176   82071   Albany County
# 578089         Ted Cruz    141           0.653   82329   Albany County
# 578090         Ted Cruz    141           0.653   82055   Albany County
# 578091         Ted Cruz    141           0.653   82070   Albany County
# 578092         Ted Cruz    141           0.653   82058   Albany County
# 578093         Ted Cruz    141           0.653   82051   Albany County
# 578094         Ted Cruz    141           0.653   82201   Albany County
# 578095         Ted Cruz    141           0.653   82059   Albany County
# 578096         Ted Cruz    141           0.653   82063   Albany County
# 578097         Ted Cruz    141           0.653   82073   Albany County
# 578098         Ted Cruz    141           0.653   82072   Albany County
# 578099         Ted Cruz    141           0.653   82083   Albany County
# 578100         Ted Cruz    141           0.653   82084   Albany County
# 578101         Ted Cruz    141           0.653   82052   Albany County
# 578102         Ted Cruz    141           0.653   82071   Albany County
#
#        state_y classfips
# 0           AL        H1
# 1           AL        H1
# 2           AL        H1
# 3           AL        H1
# 4           AL        H1
# 5           AL        H1
# 6           AL        H1
# 7           AL        H1
# 8           AL        H1
# 9           AL        H1
# 10          AL        H1
# 11          AL        H1
# 12          AL        H1
# 13          AL        H1
# 14          AL        H1
# 15          AL        H1
# 16          AL        H1
# 17          AL        H1
# 18          AL        H1
# 19          AL        H1
# 20          AL        H1
# 21          AL        H1
# 22          AL        H1
# 23          AL        H1
# 24          AL        H1
# 25          AL        H1
# 26          AL        H1
# 27          AL        H1
# 28          AL        H1
# 29          AL        H1
# ...        ...       ...
# 578073      WY        H1
# 578074      WY        H1
# 578075      WY        H1
# 578076      WY        H1
# 578077      WY        H1
# 578078      WY        H1
# 578079      WY        H1
# 578080      WY        H1
# 578081      WY        H1
# 578082      WY        H1
# 578083      WY        H1
# 578084      WY        H1
# 578085      WY        H1
# 578086      WY        H1
# 578087      WY        H1
# 578088      WY        H1
# 578089      WY        H1
# 578090      WY        H1
# 578091      WY        H1
# 578092      WY        H1
# 578093      WY        H1
# 578094      WY        H1
# 578095      WY        H1
# 578096      WY        H1
# 578097      WY        H1
# 578098      WY        H1
# 578099      WY        H1
# 578100      WY        H1
# 578101      WY        H1
# 578102      WY        H1
#
# [578103 rows x 12 columns]

# %%
df_merge.drop(['state_x','county_x','state_y','classfips'], axis=1, inplace=True)

# %%
df_merge.rename(columns={"county_y":"county"}, inplace=True)

# %%
df_merge.head()
# Out:
#   state_abbreviation   fips     party       candidate  votes  fraction_votes  \
# 0                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 1                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 2                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 3                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 4                 AL  01001  Democrat  Bernie Sanders    544           0.182
#
#   zipcode          county
# 0   36003  Autauga County
# 1   36006  Autauga County
# 2   36067  Autauga County
# 3   36066  Autauga County
# 4   36703  Autauga County

# %%
# Name of the CSV file
tax_file = 'data/tax/2014.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df_tax = pd.read_csv(tax_file, encoding="ISO-8859-1",converters={'zipcode': '{:0>5}'.format})

# %%
df_tax.head()
# Out:
#    statefips state zipcode  agi_stub    n1  mars1  mars2  mars4  prep    n2  \
# 0         25    MA   01001         1  2890   2300    290    260  1470  3130
# 1         25    MA   01001         2  2210   1360    490    320  1210  3620
# 2         25    MA   01001         3  1550    750    590    170   930  2940
# 3         25    MA   01001         4   920    240    600     70   560  2130
# 4         25    MA   01001         5  1160    190    920     40   770  3000
#
#    ...  a10300  n85530  a85530  n85300  a85300  n11901  a11901  n11902  \
# 0  ...    1161       0       0       0       0     270     220    2340
# 1  ...    5873       0       0       0       0     280     385    1900
# 2  ...    9075       0       0       0       0     300     565    1230
# 3  ...    8240       0       0       0       0     200     501     710
# 4  ...   20807       0       0       0       0     380    1548     750
#
#    a11902  year
# 0    3334  2014
# 1    4163  2014
# 2    3297  2014
# 3    2202  2014
# 4    2929  2014
#
# [5 rows x 128 columns]

# %%
df_merge_tx_clean = df_tax[['a00200','a00100','zipcode']].copy()
df_merge_tx_clean.head()
# Out:
#    a00200  a00100 zipcode
# 0   23034   33609   01001
# 1   61608   82123   01001
# 2   73264   95040   01001
# 3   60764   78961   01001
# 4  119808  151278   01001

# %%
df_final= pd.merge(df_merge, df_merge_tx_clean, how="left", on=["zipcode", "zipcode"])

# %%
df_final.head()
# Out:
#   state_abbreviation   fips     party       candidate  votes  fraction_votes  \
# 0                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 1                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 2                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 3                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 4                 AL  01001  Democrat  Bernie Sanders    544           0.182
#
#   zipcode          county  a00200  a00100
# 0   36003  Autauga County  4955.0  5526.0
# 1   36003  Autauga County  5477.0  6288.0
# 2   36003  Autauga County  3990.0  5467.0
# 3   36003  Autauga County  2992.0  4383.0
# 4   36003  Autauga County  5055.0  8231.0

# %%
df_final.rename(columns={"a00200":"Salaries","a00100":"Adjusted Gross Income"}, inplace=True)

# %%
df_final.head()
# Out:
#   state_abbreviation   fips     party       candidate  votes  fraction_votes  \
# 0                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 1                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 2                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 3                 AL  01001  Democrat  Bernie Sanders    544           0.182
# 4                 AL  01001  Democrat  Bernie Sanders    544           0.182
#
#   zipcode          county  Salaries  Adjusted Gross Income
# 0   36003  Autauga County    4955.0                 5526.0
# 1   36003  Autauga County    5477.0                 6288.0
# 2   36003  Autauga County    3990.0                 5467.0
# 3   36003  Autauga County    2992.0                 4383.0
# 4   36003  Autauga County    5055.0                 8231.0

# %%
df_final.to_excel("output.xlsx")

# %%
df_final.shape

# %%
len(df_final)
